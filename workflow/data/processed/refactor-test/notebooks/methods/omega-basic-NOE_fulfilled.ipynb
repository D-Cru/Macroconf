# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/biggin/b147/univ4859/miniconda3/envs/snakemake/lib/python3.9/site-packages', '/biggin/b147/univ4859/research/03_macroconf/workflow/rules/../notebooks']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95(\x1b\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8cOdata/processed/refactor-test/results/30/conf_gen/omega/basic/NOE_fulfilled.json\x94\x8cOdata/processed/refactor-test/results/29/conf_gen/omega/basic/NOE_fulfilled.json\x94\x8cOdata/processed/refactor-test/results/22/conf_gen/omega/basic/NOE_fulfilled.json\x94\x8cOdata/processed/refactor-test/results/52/conf_gen/omega/basic/NOE_fulfilled.json\x94\x8cOdata/processed/refactor-test/results/56/conf_gen/omega/basic/NOE_fulfilled.json\x94\x8cOdata/processed/refactor-test/results/63/conf_gen/omega/basic/NOE_fulfilled.json\x94\x8cPdata/processed/refactor-test/results/1_1/conf_gen/omega/basic/NOE_fulfilled.json\x94\x8cPdata/processed/refactor-test/results/1_2/conf_gen/omega/basic/NOE_fulfilled.json\x94\x8cOdata/processed/refactor-test/results/40/conf_gen/omega/basic/NOE_fulfilled.json\x94\x8cOdata/processed/refactor-test/results/65/conf_gen/omega/basic/NOE_fulfilled.json\x94\x8cOdata/processed/refactor-test/results/59/conf_gen/omega/basic/NOE_fulfilled.json\x94\x8cOdata/processed/refactor-test/results/50/conf_gen/omega/basic/NOE_fulfilled.json\x94\x8cOdata/processed/refactor-test/results/62/conf_gen/omega/basic/NOE_fulfilled.json\x94\x8cOdata/processed/refactor-test/results/49/conf_gen/omega/basic/NOE_fulfilled.json\x94\x8cOdata/processed/refactor-test/results/31/conf_gen/omega/basic/NOE_fulfilled.json\x94\x8cOdata/processed/refactor-test/results/39/conf_gen/omega/basic/NOE_fulfilled.json\x94\x8cOdata/processed/refactor-test/results/58/conf_gen/omega/basic/NOE_fulfilled.json\x94\x8cOdata/processed/refactor-test/results/36/conf_gen/omega/basic/NOE_fulfilled.json\x94\x8cOdata/processed/refactor-test/results/66/conf_gen/omega/basic/NOE_fulfilled.json\x94\x8cOdata/processed/refactor-test/results/24/conf_gen/omega/basic/NOE_fulfilled.json\x94\x8cOdata/processed/refactor-test/results/60/conf_gen/omega/basic/NOE_fulfilled.json\x94\x8cOdata/processed/refactor-test/results/35/conf_gen/omega/basic/NOE_fulfilled.json\x94\x8cOdata/processed/refactor-test/results/55/conf_gen/omega/basic/NOE_fulfilled.json\x94\x8cOdata/processed/refactor-test/results/32/conf_gen/omega/basic/NOE_fulfilled.json\x94\x8cOdata/processed/refactor-test/results/64/conf_gen/omega/basic/NOE_fulfilled.json\x94\x8cOdata/processed/refactor-test/results/27/conf_gen/omega/basic/NOE_fulfilled.json\x94\x8cOdata/processed/refactor-test/results/42/conf_gen/omega/basic/NOE_fulfilled.json\x94\x8cOdata/processed/refactor-test/results/51/conf_gen/omega/basic/NOE_fulfilled.json\x94\x8cOdata/processed/refactor-test/results/57/conf_gen/omega/basic/NOE_fulfilled.json\x94\x8cOdata/processed/refactor-test/results/61/conf_gen/omega/basic/NOE_fulfilled.json\x94\x8cOdata/processed/refactor-test/results/33/conf_gen/omega/basic/NOE_fulfilled.json\x94\x8cOdata/processed/refactor-test/results/68/conf_gen/omega/basic/NOE_fulfilled.json\x94\x8cOdata/processed/refactor-test/results/41/conf_gen/omega/basic/NOE_fulfilled.json\x94\x8cOdata/processed/refactor-test/results/38/conf_gen/omega/basic/NOE_fulfilled.json\x94\x8cOdata/processed/refactor-test/results/28/conf_gen/omega/basic/NOE_fulfilled.json\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\x0230\x94K\x00N\x86\x94\x8c\x0229\x94K\x01N\x86\x94\x8c\x0222\x94K\x02N\x86\x94\x8c\x0252\x94K\x03N\x86\x94\x8c\x0256\x94K\x04N\x86\x94\x8c\x0263\x94K\x05N\x86\x94\x8c\x031_1\x94K\x06N\x86\x94\x8c\x031_2\x94K\x07N\x86\x94\x8c\x0240\x94K\x08N\x86\x94\x8c\x0265\x94K\tN\x86\x94\x8c\x0259\x94K\nN\x86\x94\x8c\x0250\x94K\x0bN\x86\x94\x8c\x0262\x94K\x0cN\x86\x94\x8c\x0249\x94K\rN\x86\x94\x8c\x0231\x94K\x0eN\x86\x94\x8c\x0239\x94K\x0fN\x86\x94\x8c\x0258\x94K\x10N\x86\x94\x8c\x0236\x94K\x11N\x86\x94\x8c\x0266\x94K\x12N\x86\x94\x8c\x0224\x94K\x13N\x86\x94\x8c\x0260\x94K\x14N\x86\x94\x8c\x0235\x94K\x15N\x86\x94\x8c\x0255\x94K\x16N\x86\x94\x8c\x0232\x94K\x17N\x86\x94\x8c\x0264\x94K\x18N\x86\x94\x8c\x0227\x94K\x19N\x86\x94\x8c\x0242\x94K\x1aN\x86\x94\x8c\x0251\x94K\x1bN\x86\x94\x8c\x0257\x94K\x1cN\x86\x94\x8c\x0261\x94K\x1dN\x86\x94\x8c\x0233\x94K\x1eN\x86\x94\x8c\x0268\x94K\x1fN\x86\x94\x8c\x0241\x94K N\x86\x94\x8c\x0238\x94K!N\x86\x94\x8c\x0228\x94K"N\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94ehx\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h~)}\x94\x8c\x05_name\x94hxsNt\x94bhyh|h~\x85\x94R\x94(h~)}\x94h\x82hysNt\x94bh0h\nh2h\x0bh4h\x0ch6h\rh8h\x0eh:h\x0fh<h\x10h>h\x11h@h\x12hBh\x13hDh\x14hFh\x15hHh\x16hJh\x17hLh\x18hNh\x19hPh\x1ahRh\x1bhTh\x1chVh\x1dhXh\x1ehZh\x1fh\\h h^h!\x8c\x0264\x94h"hbh#hdh$hfh%hhh&hjh\'hlh(hnh)hph*hrh+hth,ub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94\x8cKdata/processed/refactor-test/results/methods/omega-basic-NOE_fulfilled.json\x94a}\x94(h.}\x94\x8c\x04data\x94K\x00N\x86\x94shv]\x94(hxhyehxh|h~\x85\x94R\x94(h~)}\x94h\x82hxsNt\x94bhyh|h~\x85\x94R\x94(h~)}\x94h\x82hysNt\x94bh\x90h\x8dub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94}\x94(h.}\x94hv]\x94(hxhyehxh|h~\x85\x94R\x94(h~)}\x94h\x82hxsNt\x94bhyh|h~\x85\x94R\x94(h~)}\x94h\x82hysNt\x94bub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94(\x8c\rrefactor-test\x94\x8c\x05omega\x94\x8c\x05basic\x94e}\x94(h.}\x94(\x8c\x08exp_name\x94K\x00N\x86\x94\x8c\x07confgen\x94K\x01N\x86\x94\x8c\x04mode\x94K\x02N\x86\x94uhv]\x94(hxhyehxh|h~\x85\x94R\x94(h~)}\x94h\x82hxsNt\x94bhyh|h~\x85\x94R\x94(h~)}\x94h\x82hysNt\x94b\x8c\x08exp_name\x94h\xae\x8c\x07confgen\x94h\xaf\x8c\x04mode\x94h\xb0ub\x8c\x07threads\x94K\x02\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x02K\x01\x8c\x04/tmp\x94e}\x94(h.}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uhv]\x94(hxhyehxh|h~\x85\x94R\x94(h~)}\x94h\x82hxsNt\x94bhyh|h~\x85\x94R\x94(h~)}\x94h\x82hysNt\x94bh\xcdK\x02h\xcfK\x01h\xd1h\xcaub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8cNdata/processed/refactor-test/notebooks/methods/omega-basic-NOE_fulfilled.ipynb\x94a}\x94(h.}\x94\x8c\x08notebook\x94K\x00N\x86\x94shv]\x94(hxhyehxh|h~\x85\x94R\x94(h~)}\x94h\x82hxsNt\x94bhyh|h~\x85\x94R\x94(h~)}\x94h\x82hysNt\x94bh\xe3h\xe0ub\x8c\x06config\x94}\x94(\x8c\x0bthreads_max\x94K\x0c\x8c\x04ns_h\x94G@\x1e\x00\x00\x00\x00\x00\x00\x8c\tshortened\x94\x89\x8c\x06stride\x94K\x01\x8c\x16run_single_md_analysis\x94\x88\x8c\x11run_comp_analysis\x94\x88\x8c\x14run_heatmap_analysis\x94\x89\x8c\x0frun_method_comp\x94\x89\x8c\x0frun_eq_analysis\x94\x89\x8c\trun_omega\x94\x89\x8c\trun_rdkit\x94\x89\x8c\x19run_cheminfo_NOE_analysis\x94\x89\x8c\x12make_paper_figures\x94\x88\x8c\x13update_jupyter_book\x94\x88\x8c\x12confgen_parameters\x94}\x94(\x8c\x05omega\x94]\x94(\x8c\x05basic\x94\x8c\nchloroform\x94\x8c\nlowEwindow\x94\x8c\x0bhighEwindow\x94\x8c\x06lowrms\x94\x8c\x07highrms\x94\x8c\x0bhighmaxconf\x94\x8c\thighmaxit\x94\x8c\x0chighsampling\x94\x8c\rlotsdifferent\x94e\x8c\x05rdkit\x94]\x94(\x8c\x05basic\x94\x8c\x04ETDG\x94\x8c\x07ETKDGv1\x94\x8c\x07ETKDGv2\x94\x8c\x07ETKDGv3\x94\x8c\tsrETKDGv3\x94\x8c\x03KDG\x94\x8c\x08def-ETDG\x94\x8c\x0bdef-ETKDGv1\x94\x8c\x0bdef-ETKDGv2\x94\x8c\x0bdef-ETKDGv3\x94\x8c\rdef-srETKDGv3\x94\x8c\x07def-KDG\x94\x8c\x0chighsampling\x94\x8c\rlotsdifferent\x94eu\x8c\thash_list\x94]\x94(]\x94(\x8c\x1028159d44aa267024\x94\x8c\x105ead922859f5c96d\x94\x8c\x105ead922859f5c96d\x94\x8c\x0255\x94\x8c\x010\x94j$\x01\x00\x00e]\x94(\x8c\x10250c26e1ba562237\x94\x8c\x10eff35c6c3e18f0a3\x94\x8c\x10eff35c6c3e18f0a3\x94\x8c\x0256\x94j$\x01\x00\x00j$\x01\x00\x00e]\x94(\x8c\x10210a1ea8aa678b16\x94\x8c\x103595ce0609206d95\x94\x8c\x10586db4c575bef492\x94\x8c\x0222\x94j$\x01\x00\x00j$\x01\x00\x00e]\x94(\x8c\x10210a1ea8aa678b16\x94\x8c\x10583fbeed838cced5\x94\x8c\x105405e3b785af9601\x94\x8c\x0222\x94j$\x01\x00\x00j$\x01\x00\x00e]\x94(\x8c\x10210a1ea8aa678b16\x94\x8c\x10583fbeed838cced5\x94\x8c\x105405e3b785af9601\x94\x8c\x0222\x94\x8c\x0bomega_basic\x94\x8c\x11rdkit_ETKDGv3mmff\x94e]\x94(\x8c\x10210a1ea8aa678b16\x94\x8c\x10c5389d15c56a3655\x94\x8c\x103a8c4367deb63d6e\x94\x8c\x0222\x94j$\x01\x00\x00j$\x01\x00\x00e]\x94(\x8c\x104f386944d88e6ef8\x94\x8c\x10c99bbf5d17e8efb9\x94\x8c\x10c99bbf5d17e8efb9\x94\x8c\x0224\x94j$\x01\x00\x00j$\x01\x00\x00e]\x94(\x8c\x109e61be229abfc57f\x94\x8c\x1013c5dee00c76dc47\x94\x8c\x1013c5dee00c76dc47\x94\x8c\x0249\x94j$\x01\x00\x00j$\x01\x00\x00ee\x8c\x11heatmap_compounds\x94]\x94(K\x16K\x18K7K8K!K1K2K3e\x8c\x11convergence_check\x94]\x94\x8c\x10210a1ea8aa678b16\x94a\x8c\x15run_convergence_check\x94\x89\x8c\x0ccluster_conf\x94}\x94(\x8c\x10242ee4d4af3634ed\x94K\x0f\x8c\x10c5389d15c56a3655\x94K\n\x8c\x103c523c7ca380f925\x94K\n\x8c\x10ca1a37290d9e454e\x94K\x08\x8c\x109a100624325ec4cd\x94K\x06\x8c\x103d00b0964201e088\x94K\n\x8c\x10210a1ea8aa678b16\x94K\x08u\x8c\x13full_analysis_files\x94]\x94\x8c\x9b../../../data/processed/refactor-test/notebooks/methods/28159d44aa267024-native-586db4c575bef492-native_omega-basic-rdkit-ETKDGv3mmff-NOE_method_comp.ipynb\x94a\x8c\x0fmethod_defaults\x94}\x94\x8c\x05igamd\x94}\x94(\x8c\x07methods\x94]\x94\x8c\x04GaMD\x94a\x8c\x07default\x94\x8c\x013\x94\x8c\x06others\x94\x8c\x03nan\x94us\x8c\x08exp_name\x94\x8c\rrefactor-test\x94\x8c\tdata_name\x94\x8c\x1722-02-2021_MacroConf-v2\x94\x8c\x0cdataset_file\x94\x8c3data/external/22-09-2021_MacroConf-v2.1/dataset.csv\x94\x8c\x0bsample_file\x94\x8c\x0bsamples.tsv\x94\x8c\rsample_output\x94\x8c\x0fsamples_old.tsv\x94\x8c\nforcefield\x94\x8c1libs/forcefields/leaprc.protein.ff14SB_noterminal\x94\x8c\x06jb-toc\x94\x8c\x13reports/jb/_toc.yml\x94\x8c\x08jb-links\x94\x8c\x11reports/jb/links/\x94\x8c\x0cDMSO_default\x94\x8c\x0eDMSO_GAFF_RESP\x94\x8c\rCDCl3_default\x94\x8c\nChloroform\x94\x8c\x0bDMSO_params\x94\x8c!libs/md_solvents/dmso/frcmod.dmso\x94\x8c\x08DMSO_box\x94\x8c!libs/md_solvents/dmso/dmsobox.off\x94\x8c\x11Chloroform_params\x94\x8c\x0cfrcmod.chcl3\x94u\x8c\x04rule\x94\x8c\x14confgen_comp_methods\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cG/biggin/b147/univ4859/research/03_macroconf/workflow/rules/../notebooks\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = False; import os; os.chdir(r'/biggin/b147/univ4859/research/03_macroconf/workflow');
######## snakemake preamble end #########

# %%
import src.utils
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
results = {}
for metric in ['fulfil', 'rmsd', 'mae']:
    percentage_fulfilled = {}
    energy = {}
    random = {}
    bundle_sizes = {}
    licuv = {}
    namfis = {}
    for i in snakemake.input:
        stats = src.utils.json_load(i)
        compound_id = i.split("/")[4]
        if ('cis' in stats) or ('trans' in stats):
            if ('cis' in stats):
                percentage_fulfilled[f"{compound_id}_cis"] = stats['cis'][metric]['best']
                energy[f"{compound_id}_cis"] = stats['cis'][metric]['low_energy']
                random[f"{compound_id}_cis"] = stats['cis'][metric]['random']
                bundle_sizes[f"{compound_id}_cis"] = stats['cis']['bundle-size']
                licuv[f"{compound_id}_cis"] = stats['cis'][metric]['LICUV']
                namfis[f"{compound_id}_cis"] = stats['cis'][metric]['NAMFIS']
            if ('trans' in stats):
                percentage_fulfilled[f"{compound_id}_trans"] = stats['trans'][metric]['best']
                energy[f"{compound_id}_trans"] = stats['trans'][metric]['low_energy']
                random[f"{compound_id}_trans"] = stats['trans'][metric]['random']
                bundle_sizes[f"{compound_id}_trans"] = stats['trans']['bundle-size']
                licuv[f"{compound_id}_trans"] = stats['trans'][metric]['LICUV']
                namfis[f"{compound_id}_trans"] = stats['trans'][metric]['NAMFIS']
        else:
            percentage_fulfilled[f"{compound_id}"] = stats['single'][metric]['best']
            energy[f"{compound_id}_single"] = stats['single'][metric]['low_energy']
            random[f"{compound_id}_single"] = stats['single'][metric]['random']
            bundle_sizes[f"{compound_id}_single"] = stats['single']['bundle-size']
            licuv[f"{compound_id}_single"] = stats['single'][metric]['LICUV']
            namfis[f"{compound_id}_single"] = stats['single'][metric]['NAMFIS']
    results[metric] = {
    'best': percentage_fulfilled,
    'low_energy': energy,
    'random': random,
    'bundle_size': bundle_sizes,
    'licuv': licuv,
    'namfis': namfis
    }

# %%
# plt.scatter(percentage_fulfilled.values(), percentage_fulfilled.keys(), )
#plt.title(f"{snakemake.wildcards.method}: {snakemake.wildcards.simtime} ns")
#plt.savefig(snakemake.output.plot)

# %%
src.utils.json_dump(snakemake.output.data, results)

# %%
results
# Out:
# {'fulfil': {'best': {'30': 0.36363636363636365,
#    '29': 0.3548387096774194,
#    '22': 0.6363636363636364,
#    '52_cis': 0.5,
#    '52_trans': 0.7,
#    '56': 0.3953488372093023,
#    '63': 0.7878787878787878,
#    '1_1': 0.5625,
#    '1_2': 0.5625,
#    '40': 0.3448275862068966,
#    '65': 0.6213592233009708,
#    '59': 0.6882352941176471,
#    '50_cis': 0.3076923076923077,
#    '50_trans': 0.47619047619047616,
#    '62': 0.6567164179104478,
#    '49_cis': 0.17391304347826086,
#    '49_trans': 0.4166666666666667,
#    '31': 0.4,
#    '39': 0.5483870967741935,
#    '58': 0.828125,
#    '36': 0.4090909090909091,
#    '66': 0.6808510638297872,
#    '24_cis': 0.5897435897435898,
#    '24_trans': 0.6956521739130435,
#    '60': 0.6590909090909091,
#    '35': 0.41379310344827586,
#    '55': 0.38235294117647056,
#    '32': 0.34375,
#    '64': 0.71,
#    '27': 0.44,
#    '42': 0.4482758620689655,
#    '51': 0.35,
#    '57': 0.7361111111111112,
#    '61': 0.5604395604395604,
# ...
