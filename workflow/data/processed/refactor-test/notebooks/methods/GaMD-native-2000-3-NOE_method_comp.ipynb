# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/biggin/b147/univ4859/miniconda3/envs/snakemake/lib/python3.10/site-packages', '/biggin/b147/univ4859/research/03_macroconf/workflow/rules/../notebooks']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95\xa29\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8cbdata/processed/refactor-test/results/22/DMSO_GAFF_RESP/GaMD/2000/0/583fbeed838cced5_noe_stats.json\x94\x8cbdata/processed/refactor-test/results/22/DMSO_GAFF_RESP/GaMD/2000/0/583fbeed838cced5_conv_data.json\x94\x8cWdata/processed/refactor-test/results/55/H2O/GaMD/2000/0/28159d44aa267024_noe_stats.json\x94\x8cWdata/processed/refactor-test/results/55/H2O/GaMD/2000/0/28159d44aa267024_conv_data.json\x94\x8cWdata/processed/refactor-test/results/56/H2O/GaMD/2000/0/250c26e1ba562237_noe_stats.json\x94\x8cWdata/processed/refactor-test/results/56/H2O/GaMD/2000/0/250c26e1ba562237_conv_data.json\x94\x8cWdata/processed/refactor-test/results/57/H2O/GaMD/2000/0/12cee40b82354fab_noe_stats.json\x94\x8cWdata/processed/refactor-test/results/57/H2O/GaMD/2000/0/12cee40b82354fab_conv_data.json\x94\x8cWdata/processed/refactor-test/results/58/H2O/GaMD/2000/0/d6072f62493cc5af_noe_stats.json\x94\x8cWdata/processed/refactor-test/results/58/H2O/GaMD/2000/0/d6072f62493cc5af_conv_data.json\x94\x8cWdata/processed/refactor-test/results/59/H2O/GaMD/2000/0/39f5beb490ee4833_noe_stats.json\x94\x8cWdata/processed/refactor-test/results/59/H2O/GaMD/2000/0/39f5beb490ee4833_conv_data.json\x94\x8cWdata/processed/refactor-test/results/60/H2O/GaMD/2000/0/610cc1e1311c2792_noe_stats.json\x94\x8cWdata/processed/refactor-test/results/60/H2O/GaMD/2000/0/610cc1e1311c2792_conv_data.json\x94\x8cWdata/processed/refactor-test/results/61/H2O/GaMD/2000/0/5061cfcd53f488df_noe_stats.json\x94\x8cWdata/processed/refactor-test/results/61/H2O/GaMD/2000/0/5061cfcd53f488df_conv_data.json\x94\x8cWdata/processed/refactor-test/results/62/H2O/GaMD/2000/0/ed2e9ab42cf3819c_noe_stats.json\x94\x8cWdata/processed/refactor-test/results/62/H2O/GaMD/2000/0/ed2e9ab42cf3819c_conv_data.json\x94\x8cWdata/processed/refactor-test/results/63/H2O/GaMD/2000/0/d3aa194ff18a9e75_noe_stats.json\x94\x8cWdata/processed/refactor-test/results/63/H2O/GaMD/2000/0/d3aa194ff18a9e75_conv_data.json\x94\x8cWdata/processed/refactor-test/results/64/H2O/GaMD/2000/0/eab37e4b3e032de2_noe_stats.json\x94\x8cWdata/processed/refactor-test/results/64/H2O/GaMD/2000/0/eab37e4b3e032de2_conv_data.json\x94\x8cWdata/processed/refactor-test/results/65/H2O/GaMD/2000/0/7b17fe71946f4dd7_noe_stats.json\x94\x8cWdata/processed/refactor-test/results/65/H2O/GaMD/2000/0/7b17fe71946f4dd7_conv_data.json\x94\x8cWdata/processed/refactor-test/results/66/H2O/GaMD/2000/0/bd34df1820fd3dd0_noe_stats.json\x94\x8cWdata/processed/refactor-test/results/66/H2O/GaMD/2000/0/bd34df1820fd3dd0_conv_data.json\x94\x8cWdata/processed/refactor-test/results/68/H2O/GaMD/2000/0/cd3179da84da7836_noe_stats.json\x94\x8cWdata/processed/refactor-test/results/68/H2O/GaMD/2000/0/cd3179da84da7836_conv_data.json\x94\x8c_data/processed/refactor-test/results/1_1/Chloroform/GaMD/2000/0/c1d9e06a52efb84d_noe_stats.json\x94\x8c_data/processed/refactor-test/results/1_1/Chloroform/GaMD/2000/0/c1d9e06a52efb84d_conv_data.json\x94\x8ccdata/processed/refactor-test/results/1_2/DMSO_GAFF_RESP/GaMD/2000/0/8ca570a3bee4327e_noe_stats.json\x94\x8ccdata/processed/refactor-test/results/1_2/DMSO_GAFF_RESP/GaMD/2000/0/8ca570a3bee4327e_conv_data.json\x94\x8cbdata/processed/refactor-test/results/24/DMSO_GAFF_RESP/GaMD/2000/0/069cca5a0bbb1937_noe_stats.json\x94\x8cbdata/processed/refactor-test/results/24/DMSO_GAFF_RESP/GaMD/2000/0/069cca5a0bbb1937_conv_data.json\x94\x8cbdata/processed/refactor-test/results/27/DMSO_GAFF_RESP/GaMD/2000/0/8b6552e2914a062f_noe_stats.json\x94\x8cbdata/processed/refactor-test/results/27/DMSO_GAFF_RESP/GaMD/2000/0/8b6552e2914a062f_conv_data.json\x94\x8cbdata/processed/refactor-test/results/28/DMSO_GAFF_RESP/GaMD/2000/0/babaf70b2b786682_noe_stats.json\x94\x8cbdata/processed/refactor-test/results/28/DMSO_GAFF_RESP/GaMD/2000/0/babaf70b2b786682_conv_data.json\x94\x8cbdata/processed/refactor-test/results/29/DMSO_GAFF_RESP/GaMD/2000/0/467c506b6744c831_noe_stats.json\x94\x8cbdata/processed/refactor-test/results/29/DMSO_GAFF_RESP/GaMD/2000/0/467c506b6744c831_conv_data.json\x94\x8cbdata/processed/refactor-test/results/30/DMSO_GAFF_RESP/GaMD/2000/0/58f55feb935887fb_noe_stats.json\x94\x8cbdata/processed/refactor-test/results/30/DMSO_GAFF_RESP/GaMD/2000/0/58f55feb935887fb_conv_data.json\x94\x8cbdata/processed/refactor-test/results/31/DMSO_GAFF_RESP/GaMD/2000/0/7d461adf7ab73336_noe_stats.json\x94\x8cbdata/processed/refactor-test/results/31/DMSO_GAFF_RESP/GaMD/2000/0/7d461adf7ab73336_conv_data.json\x94\x8cbdata/processed/refactor-test/results/32/DMSO_GAFF_RESP/GaMD/2000/0/b97accb0b36736bf_noe_stats.json\x94\x8cbdata/processed/refactor-test/results/32/DMSO_GAFF_RESP/GaMD/2000/0/b97accb0b36736bf_conv_data.json\x94\x8cbdata/processed/refactor-test/results/33/DMSO_GAFF_RESP/GaMD/2000/0/d13fd5c825a5a7e9_noe_stats.json\x94\x8cbdata/processed/refactor-test/results/33/DMSO_GAFF_RESP/GaMD/2000/0/d13fd5c825a5a7e9_conv_data.json\x94\x8cbdata/processed/refactor-test/results/35/DMSO_GAFF_RESP/GaMD/2000/0/6621b58bd327078d_noe_stats.json\x94\x8cbdata/processed/refactor-test/results/35/DMSO_GAFF_RESP/GaMD/2000/0/6621b58bd327078d_conv_data.json\x94\x8cbdata/processed/refactor-test/results/36/DMSO_GAFF_RESP/GaMD/2000/0/2cfb6b191b7a46f2_noe_stats.json\x94\x8cbdata/processed/refactor-test/results/36/DMSO_GAFF_RESP/GaMD/2000/0/2cfb6b191b7a46f2_conv_data.json\x94\x8cbdata/processed/refactor-test/results/38/DMSO_GAFF_RESP/GaMD/2000/0/ae576072a28ef51e_noe_stats.json\x94\x8cbdata/processed/refactor-test/results/38/DMSO_GAFF_RESP/GaMD/2000/0/ae576072a28ef51e_conv_data.json\x94\x8cbdata/processed/refactor-test/results/39/DMSO_GAFF_RESP/GaMD/2000/0/b29633ebde708f87_noe_stats.json\x94\x8cbdata/processed/refactor-test/results/39/DMSO_GAFF_RESP/GaMD/2000/0/b29633ebde708f87_conv_data.json\x94\x8cbdata/processed/refactor-test/results/40/DMSO_GAFF_RESP/GaMD/2000/0/5450f25d2ed9c22a_noe_stats.json\x94\x8cbdata/processed/refactor-test/results/40/DMSO_GAFF_RESP/GaMD/2000/0/5450f25d2ed9c22a_conv_data.json\x94\x8cbdata/processed/refactor-test/results/41/DMSO_GAFF_RESP/GaMD/2000/0/4f62f5b571b6109b_noe_stats.json\x94\x8cbdata/processed/refactor-test/results/41/DMSO_GAFF_RESP/GaMD/2000/0/4f62f5b571b6109b_conv_data.json\x94\x8cbdata/processed/refactor-test/results/42/DMSO_GAFF_RESP/GaMD/2000/0/195d188bbd583ece_noe_stats.json\x94\x8cbdata/processed/refactor-test/results/42/DMSO_GAFF_RESP/GaMD/2000/0/195d188bbd583ece_conv_data.json\x94\x8cbdata/processed/refactor-test/results/49/DMSO_GAFF_RESP/GaMD/2000/0/5b93caea6ecd1712_noe_stats.json\x94\x8cbdata/processed/refactor-test/results/49/DMSO_GAFF_RESP/GaMD/2000/0/5b93caea6ecd1712_conv_data.json\x94\x8cbdata/processed/refactor-test/results/50/DMSO_GAFF_RESP/GaMD/2000/0/5d2ce3dc4525e24d_noe_stats.json\x94\x8cbdata/processed/refactor-test/results/50/DMSO_GAFF_RESP/GaMD/2000/0/5d2ce3dc4525e24d_conv_data.json\x94\x8cbdata/processed/refactor-test/results/51/DMSO_GAFF_RESP/GaMD/2000/0/5c9adcde9c03b8b1_noe_stats.json\x94\x8cbdata/processed/refactor-test/results/51/DMSO_GAFF_RESP/GaMD/2000/0/5c9adcde9c03b8b1_conv_data.json\x94\x8cWdata/processed/refactor-test/results/52/H2O/GaMD/2000/0/5cc032301cb44666_noe_stats.json\x94\x8cWdata/processed/refactor-test/results/52/H2O/GaMD/2000/0/5cc032301cb44666_conv_data.json\x94\x8cbdata/processed/refactor-test/results/22/DMSO_GAFF_RESP/GaMD/2000/1/41d574d4866a27a1_noe_stats.json\x94\x8cbdata/processed/refactor-test/results/22/DMSO_GAFF_RESP/GaMD/2000/1/41d574d4866a27a1_conv_data.json\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\x14run_583fbeed838cced5\x94K\x00N\x86\x94\x8c\x15conv_583fbeed838cced5\x94K\x01N\x86\x94\x8c\x14run_28159d44aa267024\x94K\x02N\x86\x94\x8c\x15conv_28159d44aa267024\x94K\x03N\x86\x94\x8c\x14run_250c26e1ba562237\x94K\x04N\x86\x94\x8c\x15conv_250c26e1ba562237\x94K\x05N\x86\x94\x8c\x14run_12cee40b82354fab\x94K\x06N\x86\x94\x8c\x15conv_12cee40b82354fab\x94K\x07N\x86\x94\x8c\x14run_d6072f62493cc5af\x94K\x08N\x86\x94\x8c\x15conv_d6072f62493cc5af\x94K\tN\x86\x94\x8c\x14run_39f5beb490ee4833\x94K\nN\x86\x94\x8c\x15conv_39f5beb490ee4833\x94K\x0bN\x86\x94\x8c\x14run_610cc1e1311c2792\x94K\x0cN\x86\x94\x8c\x15conv_610cc1e1311c2792\x94K\rN\x86\x94\x8c\x14run_5061cfcd53f488df\x94K\x0eN\x86\x94\x8c\x15conv_5061cfcd53f488df\x94K\x0fN\x86\x94\x8c\x14run_ed2e9ab42cf3819c\x94K\x10N\x86\x94\x8c\x15conv_ed2e9ab42cf3819c\x94K\x11N\x86\x94\x8c\x14run_d3aa194ff18a9e75\x94K\x12N\x86\x94\x8c\x15conv_d3aa194ff18a9e75\x94K\x13N\x86\x94\x8c\x14run_eab37e4b3e032de2\x94K\x14N\x86\x94\x8c\x15conv_eab37e4b3e032de2\x94K\x15N\x86\x94\x8c\x14run_7b17fe71946f4dd7\x94K\x16N\x86\x94\x8c\x15conv_7b17fe71946f4dd7\x94K\x17N\x86\x94\x8c\x14run_bd34df1820fd3dd0\x94K\x18N\x86\x94\x8c\x15conv_bd34df1820fd3dd0\x94K\x19N\x86\x94\x8c\x14run_cd3179da84da7836\x94K\x1aN\x86\x94\x8c\x15conv_cd3179da84da7836\x94K\x1bN\x86\x94\x8c\x14run_c1d9e06a52efb84d\x94K\x1cN\x86\x94\x8c\x15conv_c1d9e06a52efb84d\x94K\x1dN\x86\x94\x8c\x14run_8ca570a3bee4327e\x94K\x1eN\x86\x94\x8c\x15conv_8ca570a3bee4327e\x94K\x1fN\x86\x94\x8c\x14run_069cca5a0bbb1937\x94K N\x86\x94\x8c\x15conv_069cca5a0bbb1937\x94K!N\x86\x94\x8c\x14run_8b6552e2914a062f\x94K"N\x86\x94\x8c\x15conv_8b6552e2914a062f\x94K#N\x86\x94\x8c\x14run_babaf70b2b786682\x94K$N\x86\x94\x8c\x15conv_babaf70b2b786682\x94K%N\x86\x94\x8c\x14run_467c506b6744c831\x94K&N\x86\x94\x8c\x15conv_467c506b6744c831\x94K\'N\x86\x94\x8c\x14run_58f55feb935887fb\x94K(N\x86\x94\x8c\x15conv_58f55feb935887fb\x94K)N\x86\x94\x8c\x14run_7d461adf7ab73336\x94K*N\x86\x94\x8c\x15conv_7d461adf7ab73336\x94K+N\x86\x94\x8c\x14run_b97accb0b36736bf\x94K,N\x86\x94\x8c\x15conv_b97accb0b36736bf\x94K-N\x86\x94\x8c\x14run_d13fd5c825a5a7e9\x94K.N\x86\x94\x8c\x15conv_d13fd5c825a5a7e9\x94K/N\x86\x94\x8c\x14run_6621b58bd327078d\x94K0N\x86\x94\x8c\x15conv_6621b58bd327078d\x94K1N\x86\x94\x8c\x14run_2cfb6b191b7a46f2\x94K2N\x86\x94\x8c\x15conv_2cfb6b191b7a46f2\x94K3N\x86\x94\x8c\x14run_ae576072a28ef51e\x94K4N\x86\x94\x8c\x15conv_ae576072a28ef51e\x94K5N\x86\x94\x8c\x14run_b29633ebde708f87\x94K6N\x86\x94\x8c\x15conv_b29633ebde708f87\x94K7N\x86\x94\x8c\x14run_5450f25d2ed9c22a\x94K8N\x86\x94\x8c\x15conv_5450f25d2ed9c22a\x94K9N\x86\x94\x8c\x14run_4f62f5b571b6109b\x94K:N\x86\x94\x8c\x15conv_4f62f5b571b6109b\x94K;N\x86\x94\x8c\x14run_195d188bbd583ece\x94K<N\x86\x94\x8c\x15conv_195d188bbd583ece\x94K=N\x86\x94\x8c\x14run_5b93caea6ecd1712\x94K>N\x86\x94\x8c\x15conv_5b93caea6ecd1712\x94K?N\x86\x94\x8c\x14run_5d2ce3dc4525e24d\x94K@N\x86\x94\x8c\x15conv_5d2ce3dc4525e24d\x94KAN\x86\x94\x8c\x14run_5c9adcde9c03b8b1\x94KBN\x86\x94\x8c\x15conv_5c9adcde9c03b8b1\x94KCN\x86\x94\x8c\x14run_5cc032301cb44666\x94KDN\x86\x94\x8c\x15conv_5cc032301cb44666\x94KEN\x86\x94\x8c\x14run_41d574d4866a27a1\x94KFN\x86\x94\x8c\x15conv_41d574d4866a27a1\x94KGN\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\xe7\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h\xed)}\x94\x8c\x05_name\x94h\xe7sNt\x94bh\xe8h\xebh\xed\x85\x94R\x94(h\xed)}\x94h\xf1h\xe8sNt\x94b\x8c\x14run_583fbeed838cced5\x94h\n\x8c\x15conv_583fbeed838cced5\x94h\x0b\x8c\x14run_28159d44aa267024\x94h\x0c\x8c\x15conv_28159d44aa267024\x94h\r\x8c\x14run_250c26e1ba562237\x94h\x0e\x8c\x15conv_250c26e1ba562237\x94h\x0f\x8c\x14run_12cee40b82354fab\x94h\x10\x8c\x15conv_12cee40b82354fab\x94h\x11\x8c\x14run_d6072f62493cc5af\x94h\x12\x8c\x15conv_d6072f62493cc5af\x94h\x13\x8c\x14run_39f5beb490ee4833\x94h\x14\x8c\x15conv_39f5beb490ee4833\x94h\x15\x8c\x14run_610cc1e1311c2792\x94h\x16\x8c\x15conv_610cc1e1311c2792\x94h\x17\x8c\x14run_5061cfcd53f488df\x94h\x18\x8c\x15conv_5061cfcd53f488df\x94h\x19\x8c\x14run_ed2e9ab42cf3819c\x94h\x1a\x8c\x15conv_ed2e9ab42cf3819c\x94h\x1b\x8c\x14run_d3aa194ff18a9e75\x94h\x1c\x8c\x15conv_d3aa194ff18a9e75\x94h\x1d\x8c\x14run_eab37e4b3e032de2\x94h\x1e\x8c\x15conv_eab37e4b3e032de2\x94h\x1f\x8c\x14run_7b17fe71946f4dd7\x94h \x8c\x15conv_7b17fe71946f4dd7\x94h!\x8c\x14run_bd34df1820fd3dd0\x94h"\x8c\x15conv_bd34df1820fd3dd0\x94h#\x8c\x14run_cd3179da84da7836\x94h$\x8c\x15conv_cd3179da84da7836\x94h%\x8c\x14run_c1d9e06a52efb84d\x94h&\x8c\x15conv_c1d9e06a52efb84d\x94h\'\x8c\x14run_8ca570a3bee4327e\x94h(\x8c\x15conv_8ca570a3bee4327e\x94h)\x8c\x14run_069cca5a0bbb1937\x94h*\x8c\x15conv_069cca5a0bbb1937\x94h+\x8c\x14run_8b6552e2914a062f\x94h,\x8c\x15conv_8b6552e2914a062f\x94h-\x8c\x14run_babaf70b2b786682\x94h.\x8c\x15conv_babaf70b2b786682\x94h/\x8c\x14run_467c506b6744c831\x94h0\x8c\x15conv_467c506b6744c831\x94h1\x8c\x14run_58f55feb935887fb\x94h2\x8c\x15conv_58f55feb935887fb\x94h3\x8c\x14run_7d461adf7ab73336\x94h4\x8c\x15conv_7d461adf7ab73336\x94h5\x8c\x14run_b97accb0b36736bf\x94h6\x8c\x15conv_b97accb0b36736bf\x94h7\x8c\x14run_d13fd5c825a5a7e9\x94h8\x8c\x15conv_d13fd5c825a5a7e9\x94h9\x8c\x14run_6621b58bd327078d\x94h:\x8c\x15conv_6621b58bd327078d\x94h;\x8c\x14run_2cfb6b191b7a46f2\x94h<\x8c\x15conv_2cfb6b191b7a46f2\x94h=\x8c\x14run_ae576072a28ef51e\x94h>\x8c\x15conv_ae576072a28ef51e\x94h?\x8c\x14run_b29633ebde708f87\x94h@\x8c\x15conv_b29633ebde708f87\x94hA\x8c\x14run_5450f25d2ed9c22a\x94hB\x8c\x15conv_5450f25d2ed9c22a\x94hC\x8c\x14run_4f62f5b571b6109b\x94hD\x8c\x15conv_4f62f5b571b6109b\x94hE\x8c\x14run_195d188bbd583ece\x94hF\x8c\x15conv_195d188bbd583ece\x94hG\x8c\x14run_5b93caea6ecd1712\x94hH\x8c\x15conv_5b93caea6ecd1712\x94hI\x8c\x14run_5d2ce3dc4525e24d\x94hJ\x8c\x15conv_5d2ce3dc4525e24d\x94hK\x8c\x14run_5c9adcde9c03b8b1\x94hL\x8c\x15conv_5c9adcde9c03b8b1\x94hM\x8c\x14run_5cc032301cb44666\x94hN\x8c\x15conv_5cc032301cb44666\x94hO\x8c\x14run_41d574d4866a27a1\x94hP\x8c\x15conv_41d574d4866a27a1\x94hQub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94(\x8cGdata/processed/refactor-test/results/methods/GaMD-native-2000-3-NOE.png\x94\x8cRdata/processed/refactor-test/results/methods/GaMD-native-2000-3-NOE_fulfilled.json\x94\x8cMdata/processed/refactor-test/results/methods/GaMD-native-2000-3-conv_plot.svg\x94e}\x94(hS}\x94(\x8c\x04plot\x94K\x00N\x86\x94\x8c\x04data\x94K\x01N\x86\x94\x8c\tconv_plot\x94K\x02N\x86\x94uh\xe5]\x94(h\xe7h\xe8eh\xe7h\xebh\xed\x85\x94R\x94(h\xed)}\x94h\xf1h\xe7sNt\x94bh\xe8h\xebh\xed\x85\x94R\x94(h\xed)}\x94h\xf1h\xe8sNt\x94bjH\x01\x00\x00jC\x01\x00\x00jJ\x01\x00\x00jD\x01\x00\x00jL\x01\x00\x00jE\x01\x00\x00ub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94}\x94(hS}\x94h\xe5]\x94(h\xe7h\xe8eh\xe7h\xebh\xed\x85\x94R\x94(h\xed)}\x94h\xf1h\xe7sNt\x94bh\xe8h\xebh\xed\x85\x94R\x94(h\xed)}\x94h\xf1h\xe8sNt\x94bub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94(\x8c\rrefactor-test\x94\x8c\x04GaMD\x94\x8c\x06native\x94\x8c\x042000\x94\x8c\x013\x94e}\x94(hS}\x94(\x8c\x08exp_name\x94K\x00N\x86\x94\x8c\x06method\x94K\x01N\x86\x94\x8c\x07solvent\x94K\x02N\x86\x94\x8c\x07simtime\x94K\x03N\x86\x94\x8c\x05igamd\x94K\x04N\x86\x94uh\xe5]\x94(h\xe7h\xe8eh\xe7h\xebh\xed\x85\x94R\x94(h\xed)}\x94h\xf1h\xe7sNt\x94bh\xe8h\xebh\xed\x85\x94R\x94(h\xed)}\x94h\xf1h\xe8sNt\x94b\x8c\x08exp_name\x94jj\x01\x00\x00\x8c\x06method\x94jk\x01\x00\x00\x8c\x07solvent\x94jl\x01\x00\x00\x8c\x07simtime\x94jm\x01\x00\x00\x8c\x05igamd\x94jn\x01\x00\x00ub\x8c\x07threads\x94K\x02\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x02K\x01\x8c\x04/tmp\x94e}\x94(hS}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh\xe5]\x94(h\xe7h\xe8eh\xe7h\xebh\xed\x85\x94R\x94(h\xed)}\x94h\xf1h\xe7sNt\x94bh\xe8h\xebh\xed\x85\x94R\x94(h\xed)}\x94h\xf1h\xe8sNt\x94bj\x91\x01\x00\x00K\x02j\x93\x01\x00\x00K\x01j\x95\x01\x00\x00j\x8e\x01\x00\x00ub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8cWdata/processed/refactor-test/notebooks/methods/GaMD-native-2000-3-NOE_method_comp.ipynb\x94a}\x94(hS}\x94\x8c\x08notebook\x94K\x00N\x86\x94sh\xe5]\x94(h\xe7h\xe8eh\xe7h\xebh\xed\x85\x94R\x94(h\xed)}\x94h\xf1h\xe7sNt\x94bh\xe8h\xebh\xed\x85\x94R\x94(h\xed)}\x94h\xf1h\xe8sNt\x94bj\xa7\x01\x00\x00j\xa4\x01\x00\x00ub\x8c\x06config\x94}\x94(\x8c\x0bthreads_max\x94K\x0c\x8c\x16run_single_md_analysis\x94\x89\x8c\x11run_comp_analysis\x94\x89\x8c\x14run_heatmap_analysis\x94\x89\x8c\x0frun_method_comp\x94\x89\x8c\x0frun_eq_analysis\x94\x89\x8c\trun_omega\x94\x89\x8c\trun_rdkit\x94\x89\x8c\x19run_cheminfo_NOE_analysis\x94\x89\x8c\x12make_paper_figures\x94\x88\x8c\x13update_jupyter_book\x94\x88\x8c\x11convergence_check\x94]\x94\x8c\x10210a1ea8aa678b16\x94a\x8c\x15run_convergence_check\x94\x89\x8c\x0fmethod_defaults\x94}\x94\x8c\x05igamd\x94}\x94(\x8c\x07methods\x94]\x94\x8c\x04GaMD\x94a\x8c\x07default\x94jn\x01\x00\x00\x8c\x06others\x94\x8c\x03nan\x94us\x8c\tshortened\x94\x89\x8c\x06stride\x94K\x01\x8c\x04ns_h\x94G@\x1e\x00\x00\x00\x00\x00\x00\x8c\thash_list\x94]\x94(]\x94(\x8c\x1028159d44aa267024\x94\x8c\x105ead922859f5c96d\x94\x8c\x105ead922859f5c96d\x94\x8c\x0255\x94\x8c\x010\x94j\xd7\x01\x00\x00e]\x94(\x8c\x10250c26e1ba562237\x94\x8c\x10eff35c6c3e18f0a3\x94\x8c\x10eff35c6c3e18f0a3\x94\x8c\x0256\x94j\xd7\x01\x00\x00j\xd7\x01\x00\x00e]\x94(\x8c\x10210a1ea8aa678b16\x94\x8c\x103595ce0609206d95\x94\x8c\x10586db4c575bef492\x94\x8c\x0222\x94j\xd7\x01\x00\x00j\xd7\x01\x00\x00e]\x94(\x8c\x10210a1ea8aa678b16\x94\x8c\x10583fbeed838cced5\x94\x8c\x105405e3b785af9601\x94\x8c\x0222\x94j\xd7\x01\x00\x00j\xd7\x01\x00\x00e]\x94(\x8c\x10210a1ea8aa678b16\x94\x8c\x10583fbeed838cced5\x94\x8c\x105405e3b785af9601\x94\x8c\x0222\x94\x8c\x0bomega_basic\x94\x8c\x11rdkit_ETKDGv3mmff\x94e]\x94(\x8c\x10210a1ea8aa678b16\x94\x8c\x10c5389d15c56a3655\x94\x8c\x103a8c4367deb63d6e\x94\x8c\x0222\x94j\xd7\x01\x00\x00j\xd7\x01\x00\x00e]\x94(\x8c\x104f386944d88e6ef8\x94\x8c\x10c99bbf5d17e8efb9\x94\x8c\x10c99bbf5d17e8efb9\x94\x8c\x0224\x94j\xd7\x01\x00\x00j\xd7\x01\x00\x00e]\x94(\x8c\x109e61be229abfc57f\x94\x8c\x1013c5dee00c76dc47\x94\x8c\x1013c5dee00c76dc47\x94\x8c\x0249\x94j\xd7\x01\x00\x00j\xd7\x01\x00\x00ee\x8c\x12confgen_parameters\x94}\x94(\x8c\x05omega\x94]\x94(\x8c\x05basic\x94\x8c\nchloroform\x94\x8c\nlowEwindow\x94\x8c\x0bhighEwindow\x94\x8c\x06lowrms\x94\x8c\x07highrms\x94\x8c\x0bhighmaxconf\x94\x8c\thighmaxit\x94\x8c\x0chighsampling\x94\x8c\rlotsdifferent\x94e\x8c\x05rdkit\x94]\x94(\x8c\x05basic\x94\x8c\x04ETDG\x94\x8c\x07ETKDGv1\x94\x8c\x07ETKDGv2\x94\x8c\x07ETKDGv3\x94\x8c\tsrETKDGv3\x94\x8c\x03KDG\x94\x8c\x08def-ETDG\x94\x8c\x0bdef-ETKDGv1\x94\x8c\x0bdef-ETKDGv2\x94\x8c\x0bdef-ETKDGv3\x94\x8c\rdef-srETKDGv3\x94\x8c\x07def-KDG\x94\x8c\x0chighsampling\x94\x8c\rlotsdifferent\x94eu\x8c\x11heatmap_compounds\x94]\x94(K\x16K\x18K7K8K!K1K2K3e\x8c\x0ccluster_conf\x94}\x94(\x8c\x10242ee4d4af3634ed\x94K\x0f\x8c\x10c5389d15c56a3655\x94K\n\x8c\x103c523c7ca380f925\x94K\n\x8c\x10ca1a37290d9e454e\x94K\x08\x8c\x109a100624325ec4cd\x94K\x06\x8c\x103d00b0964201e088\x94K\n\x8c\x10210a1ea8aa678b16\x94K\x08u\x8c\x08exp_name\x94\x8c\rrefactor-test\x94\x8c\tdata_name\x94\x8c\x1722-02-2021_MacroConf-v2\x94\x8c\x0cdataset_file\x94\x8c3data/external/22-09-2021_MacroConf-v2.1/dataset.csv\x94\x8c\x0bsample_file\x94\x8c\x0bsamples.tsv\x94\x8c\rsample_output\x94\x8c\x0fsamples_old.tsv\x94\x8c\nforcefield\x94\x8c1libs/forcefields/leaprc.protein.ff14SB_noterminal\x94\x8c\x06jb-toc\x94\x8c\x13reports/jb/_toc.yml\x94\x8c\x08jb-links\x94\x8c\x11reports/jb/links/\x94\x8c\x0cDMSO_default\x94\x8c\x0eDMSO_GAFF_RESP\x94\x8c\rCDCl3_default\x94\x8c\nChloroform\x94\x8c\x0bDMSO_params\x94\x8c!libs/md_solvents/dmso/frcmod.dmso\x94\x8c\x08DMSO_box\x94\x8c!libs/md_solvents/dmso/dmsobox.off\x94\x8c\x11Chloroform_params\x94\x8c\x0cfrcmod.chcl3\x94\x8c\x13full_analysis_files\x94]\x94\x8c\x9b../../../data/processed/refactor-test/notebooks/methods/28159d44aa267024-native-586db4c575bef492-native_omega-basic-rdkit-ETKDGv3mmff-NOE_method_comp.ipynb\x94au\x8c\x04rule\x94\x8c\x0fmd_comp_methods\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cG/biggin/b147/univ4859/research/03_macroconf/workflow/rules/../notebooks\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = False; import os; os.chdir(r'/biggin/b147/univ4859/research/03_macroconf/workflow');
######## snakemake preamble end #########

# %%
import src.utils
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
stats_i = src.utils.json_load(snakemake.input[0])
_, v = next(iter(stats_i.items()))
v = pd.DataFrame.from_dict(v)
v = v.columns.to_list()
remover = ["stat", "up", "low"]
[v.remove(r) for r in remover]
# Make temp storage
percentage_fulfilled = {}
rmsd = {}
mae = {}
rmsd_stepwise = {}
# for different bundles
for i in v:
    percentage_fulfilled[i] = {}
    rmsd[i] = {}
    mae[i] = {}
    rmsd_stepwise[i] = {}

for i in snakemake.input:
    # if filename ends with stats.json
    if i[-10:] == "stats.json":
        for j in v:
            stats = src.utils.json_load(i)
            hash = i[-31:-15]
            compound_id = i.split("/")[4]

            for k in stats.keys():
                stats_df = pd.DataFrame.from_dict(stats[k])
                percentage_fulfilled[j][f"{hash}-{compound_id}_{k}"] = stats_df[
                    stats_df["stat"] == "percentage_fulfilled"
                ][j].values.tolist()[0]
                rmsd[j][f"{hash}-{compound_id}_{k}"] = stats_df[
                    stats_df["stat"] == "RMSD"
                ][j].values.tolist()[0]
                mae[j][f"{hash}-{compound_id}_{k}"] = stats_df[
                    stats_df["stat"] == "MAE"
                ][j].values.tolist()[0]
                rmsd_stepwise[j][f"{hash}-{compound_id}_{k}"] = stats_df[
                    stats_df["stat"] == "RMSD_step"
                ][j].values.tolist()[0]
            


######
#         multiple = False
#         if "cis" in stats or "trans" in stats:
#             multiple = True
#         if multiple:
#             stats_cis = stats.cis
#             stats_trans = stats.trans
#             stats_cis = pd.DataFrame.from_dict(stats_cis)
#             stats_trans = pd.DataFrame.from_dict(stats_trans)
#         else:
#             test_NOE = pd.read_json(i)

#         if multiple:
#             if "stat" in stats_cis:
#                 percentage_fulfilled[f"{hash}-{compound_id}_cis"] = stats_cis[stats_cis['stat'] == 'percentage_fulfilled'].value.values.tolist()[0]
#                 rmsd[f"{hash}-{compound_id}_cis"] = stats_cis[stats_cis['stat'] == 'RMSD'].value.values.tolist()[0]
#                 mae[f"{hash}-{compound_id}_cis"] = stats_cis[stats_cis['stat'] == 'MAE'].value.values.tolist()[0]
#             if "stat" in stats_trans:
#                 percentage_fulfilled[f"{hash}-{compound_id}_trans"] = stats_trans[stats_trans['stat'] == 'percentage_fulfilled'].value.values.tolist()[0]
#                 rmsd[f"{hash}-{compound_id}_trans"] = stats_trans[stats_trans['stat'] == 'RMSD'].value.values.tolist()[0]
#                 mae[f"{hash}-{compound_id}_trans"] = stats_trans[stats_trans['stat'] == 'MAE'].value.values.tolist()[0]
#         else:
#             percentage_fulfilled[f"{hash}-{compound_id}"] = test_NOE[test_NOE['stat'] == 'percentage_fulfilled'].value.values.tolist()[0]
#             rmsd[f"{hash}-{compound_id}"] = test_NOE[test_NOE['stat'] == 'RMSD'].value.values.tolist()[0]
#             mae[f"{hash}-{compound_id}"] = test_NOE[test_NOE['stat'] == 'MAE'].value.values.tolist()[0]

# %%
stats_i
# Out:
# {'single': {'stat': {'0': 'MAE',
#    '1': 'MSE',
#    '2': 'RMSD',
#    '3': 'RMSD_step',
#    '4': 'pearsonr',
#    '5': 'kendalltau',
#    '6': 'chisq',
#    '7': 'percentage_fulfilled'},
#   'value': {'0': 0.5507782049648882,
#    '1': 0.4253716070562758,
#    '2': 0.7223100520945044,
#    '3': 0.3225537305487399,
#    '4': 0.3191426539363893,
#    '5': 0.23427387005083175,
#    '6': 5.267253362552286,
#    '7': 0.5909090909090909},
#   'up': {'0': 0.7682419466574308,
#    '1': 0.6828368672933317,
#    '2': 0.9910117743195912,
#    '3': 0.5191615836337121,
#    '4': 0.7039714624907594,
#    '5': 0.5818181818181819,
#    '6': 10.787926693342566,
#    '7': 0.0},
#   'low': {'0': 0.3740572630672282,
#    '1': 0.1945174233095845,
#    '2': 0.4480244633286778,
#    '3': 0.1195626498430299,
#    '4': 0.0,
#    '5': 0.0,
#    '6': 1.805134446101086,
#    '7': 0.0},
#   'most-populated-1': {'0': 0.6653179576180196,
#    '1': 0.5543167911876329,
#    '2': 0.8346647602032334,
# ...

# %%
plt.scatter(
    percentage_fulfilled["value"].values(),
    percentage_fulfilled["value"].keys(),
)
plt.title(f"{snakemake.wildcards.method}: {snakemake.wildcards.simtime} ns")
plt.savefig(snakemake.output.plot)

# %%
output = {
    "RMSD": rmsd,
    "MAE": mae,
    "percentage_fulfilled": percentage_fulfilled,
    "RMSD_stepwise": rmsd_stepwise,
}

# %%
output
# Out:
# {'RMSD': {'value': {'583fbeed838cced5-22_single': 0.7223100520945044,
#    '28159d44aa267024-55_single': 0.4642069030218824,
#    '250c26e1ba562237-56_single': 0.8091660296713371,
#    '12cee40b82354fab-57_single': 1.1057330447214413,
#    'd6072f62493cc5af-58_single': 0.9614798734993473,
#    '39f5beb490ee4833-59_single': 0.8821757704221712,
#    '610cc1e1311c2792-60_single': 1.058128992582093,
#    '5061cfcd53f488df-61_single': 1.2098032764279774,
#    'ed2e9ab42cf3819c-62_single': 0.8045585550209454,
#    'd3aa194ff18a9e75-63_single': 1.1742356976201274,
#    'eab37e4b3e032de2-64_single': 1.1894428638013386,
#    '7b17fe71946f4dd7-65_single': 1.2995757852102738,
#    'bd34df1820fd3dd0-66_single': 1.335593354817479,
#    'cd3179da84da7836-68_single': 0.9017277920731401,
#    'c1d9e06a52efb84d-1_1_single': 0.27868963237844774,
#    '8ca570a3bee4327e-1_2_single': 0.3484472239437704,
#    '069cca5a0bbb1937-24_cis': 0.6740203219326274,
# ...

# %%
src.utils.json_dump(snakemake.output.data, output)
from src.utils import json_load

# %%
conv_block = {} 
conv_time = {}

for f in snakemake.input:
    # if filename ends with conv_data.json
    if f[-14:] == "conv_data.json":
        id = f.split('/')[4]
        compound_data = json_load(f)
        conv_block[id] = compound_data['converged_block']
        conv_time[id] = compound_data['converged_time']

# %%
plt.hist(conv_time.values())
plt.xlabel('Convergence time [ns]')
plt.ylabel('No. of simulations')
plt.savefig(snakemake.output.conv_plot, dpi=600)

# %%
import pandas as pd
df = pd.Series(conv_time, name='ConvTime')
df.describe()
# Out:
# count      35.000000
# mean      922.857143
# std       530.308298
# min       100.000000
# 25%       500.000000
# 50%       900.000000
# 75%      1300.000000
# max      2000.000000
# Name: ConvTime, dtype: float64

# %%
# print full df
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(df)
# Out:
# 22      600
# 55     1100
# 56     1300
# 57      900
# 58     1700
# 59      400
# 60      300
# 61     1700
# 62     1400
# 63     1400
# 64      700
# 65      300
# 66      500
# 68      800
# 1_1     700
# 1_2     200
# 24     1300
# 27     1800
# 28      400
# 29     1000
# 30     2000
# 31      700
# 32     1200
# 33      800
# 35      900
# 36      100
# 38     1100
# 39     1200
# 40      500
# 41      100
# 42      300
# 49     1900
# 50      700
# 51     1400
# 52      900
# Name: ConvTime, dtype: int64
