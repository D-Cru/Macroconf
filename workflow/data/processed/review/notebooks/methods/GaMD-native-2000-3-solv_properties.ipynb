# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/biggin/b147/univ4859/miniconda3/envs/snakemake/lib/python3.10/site-packages', '/biggin/b147/univ4859/research/03_macroconf/workflow/rules/../notebooks']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95\x17%\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8cmdata/processed/refactor-test/results/22/DMSO_GAFF_RESP/GaMD/2000/0/583fbeed838cced5_solvation_properties.json\x94\x8cbdata/processed/refactor-test/results/55/H2O/GaMD/2000/0/28159d44aa267024_solvation_properties.json\x94\x8cbdata/processed/refactor-test/results/56/H2O/GaMD/2000/0/250c26e1ba562237_solvation_properties.json\x94\x8cbdata/processed/refactor-test/results/57/H2O/GaMD/2000/0/12cee40b82354fab_solvation_properties.json\x94\x8cbdata/processed/refactor-test/results/58/H2O/GaMD/2000/0/d6072f62493cc5af_solvation_properties.json\x94\x8cbdata/processed/refactor-test/results/59/H2O/GaMD/2000/0/39f5beb490ee4833_solvation_properties.json\x94\x8cbdata/processed/refactor-test/results/60/H2O/GaMD/2000/0/610cc1e1311c2792_solvation_properties.json\x94\x8cbdata/processed/refactor-test/results/61/H2O/GaMD/2000/0/5061cfcd53f488df_solvation_properties.json\x94\x8cbdata/processed/refactor-test/results/62/H2O/GaMD/2000/0/ed2e9ab42cf3819c_solvation_properties.json\x94\x8cbdata/processed/refactor-test/results/63/H2O/GaMD/2000/0/d3aa194ff18a9e75_solvation_properties.json\x94\x8cbdata/processed/refactor-test/results/64/H2O/GaMD/2000/0/eab37e4b3e032de2_solvation_properties.json\x94\x8cbdata/processed/refactor-test/results/65/H2O/GaMD/2000/0/7b17fe71946f4dd7_solvation_properties.json\x94\x8cbdata/processed/refactor-test/results/66/H2O/GaMD/2000/0/bd34df1820fd3dd0_solvation_properties.json\x94\x8cbdata/processed/refactor-test/results/68/H2O/GaMD/2000/0/cd3179da84da7836_solvation_properties.json\x94\x8cjdata/processed/refactor-test/results/1_1/Chloroform/GaMD/2000/0/c1d9e06a52efb84d_solvation_properties.json\x94\x8cndata/processed/refactor-test/results/1_2/DMSO_GAFF_RESP/GaMD/2000/0/8ca570a3bee4327e_solvation_properties.json\x94\x8cmdata/processed/refactor-test/results/24/DMSO_GAFF_RESP/GaMD/2000/0/069cca5a0bbb1937_solvation_properties.json\x94\x8cmdata/processed/refactor-test/results/27/DMSO_GAFF_RESP/GaMD/2000/0/8b6552e2914a062f_solvation_properties.json\x94\x8cmdata/processed/refactor-test/results/28/DMSO_GAFF_RESP/GaMD/2000/0/babaf70b2b786682_solvation_properties.json\x94\x8cmdata/processed/refactor-test/results/29/DMSO_GAFF_RESP/GaMD/2000/0/467c506b6744c831_solvation_properties.json\x94\x8cmdata/processed/refactor-test/results/30/DMSO_GAFF_RESP/GaMD/2000/0/58f55feb935887fb_solvation_properties.json\x94\x8cmdata/processed/refactor-test/results/31/DMSO_GAFF_RESP/GaMD/2000/0/7d461adf7ab73336_solvation_properties.json\x94\x8cmdata/processed/refactor-test/results/32/DMSO_GAFF_RESP/GaMD/2000/0/b97accb0b36736bf_solvation_properties.json\x94\x8cmdata/processed/refactor-test/results/33/DMSO_GAFF_RESP/GaMD/2000/0/d13fd5c825a5a7e9_solvation_properties.json\x94\x8cmdata/processed/refactor-test/results/35/DMSO_GAFF_RESP/GaMD/2000/0/6621b58bd327078d_solvation_properties.json\x94\x8cmdata/processed/refactor-test/results/36/DMSO_GAFF_RESP/GaMD/2000/0/2cfb6b191b7a46f2_solvation_properties.json\x94\x8cmdata/processed/refactor-test/results/38/DMSO_GAFF_RESP/GaMD/2000/0/ae576072a28ef51e_solvation_properties.json\x94\x8cmdata/processed/refactor-test/results/39/DMSO_GAFF_RESP/GaMD/2000/0/b29633ebde708f87_solvation_properties.json\x94\x8cmdata/processed/refactor-test/results/40/DMSO_GAFF_RESP/GaMD/2000/0/5450f25d2ed9c22a_solvation_properties.json\x94\x8cmdata/processed/refactor-test/results/41/DMSO_GAFF_RESP/GaMD/2000/0/4f62f5b571b6109b_solvation_properties.json\x94\x8cmdata/processed/refactor-test/results/42/DMSO_GAFF_RESP/GaMD/2000/0/195d188bbd583ece_solvation_properties.json\x94\x8cmdata/processed/refactor-test/results/49/DMSO_GAFF_RESP/GaMD/2000/0/5b93caea6ecd1712_solvation_properties.json\x94\x8cmdata/processed/refactor-test/results/50/DMSO_GAFF_RESP/GaMD/2000/0/5d2ce3dc4525e24d_solvation_properties.json\x94\x8cmdata/processed/refactor-test/results/51/DMSO_GAFF_RESP/GaMD/2000/0/5c9adcde9c03b8b1_solvation_properties.json\x94\x8cbdata/processed/refactor-test/results/52/H2O/GaMD/2000/0/5cc032301cb44666_solvation_properties.json\x94\x8cmdata/processed/refactor-test/results/22/DMSO_GAFF_RESP/GaMD/2000/1/41d574d4866a27a1_solvation_properties.json\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\x14run_583fbeed838cced5\x94K\x00N\x86\x94\x8c\x14run_28159d44aa267024\x94K\x01N\x86\x94\x8c\x14run_250c26e1ba562237\x94K\x02N\x86\x94\x8c\x14run_12cee40b82354fab\x94K\x03N\x86\x94\x8c\x14run_d6072f62493cc5af\x94K\x04N\x86\x94\x8c\x14run_39f5beb490ee4833\x94K\x05N\x86\x94\x8c\x14run_610cc1e1311c2792\x94K\x06N\x86\x94\x8c\x14run_5061cfcd53f488df\x94K\x07N\x86\x94\x8c\x14run_ed2e9ab42cf3819c\x94K\x08N\x86\x94\x8c\x14run_d3aa194ff18a9e75\x94K\tN\x86\x94\x8c\x14run_eab37e4b3e032de2\x94K\nN\x86\x94\x8c\x14run_7b17fe71946f4dd7\x94K\x0bN\x86\x94\x8c\x14run_bd34df1820fd3dd0\x94K\x0cN\x86\x94\x8c\x14run_cd3179da84da7836\x94K\rN\x86\x94\x8c\x14run_c1d9e06a52efb84d\x94K\x0eN\x86\x94\x8c\x14run_8ca570a3bee4327e\x94K\x0fN\x86\x94\x8c\x14run_069cca5a0bbb1937\x94K\x10N\x86\x94\x8c\x14run_8b6552e2914a062f\x94K\x11N\x86\x94\x8c\x14run_babaf70b2b786682\x94K\x12N\x86\x94\x8c\x14run_467c506b6744c831\x94K\x13N\x86\x94\x8c\x14run_58f55feb935887fb\x94K\x14N\x86\x94\x8c\x14run_7d461adf7ab73336\x94K\x15N\x86\x94\x8c\x14run_b97accb0b36736bf\x94K\x16N\x86\x94\x8c\x14run_d13fd5c825a5a7e9\x94K\x17N\x86\x94\x8c\x14run_6621b58bd327078d\x94K\x18N\x86\x94\x8c\x14run_2cfb6b191b7a46f2\x94K\x19N\x86\x94\x8c\x14run_ae576072a28ef51e\x94K\x1aN\x86\x94\x8c\x14run_b29633ebde708f87\x94K\x1bN\x86\x94\x8c\x14run_5450f25d2ed9c22a\x94K\x1cN\x86\x94\x8c\x14run_4f62f5b571b6109b\x94K\x1dN\x86\x94\x8c\x14run_195d188bbd583ece\x94K\x1eN\x86\x94\x8c\x14run_5b93caea6ecd1712\x94K\x1fN\x86\x94\x8c\x14run_5d2ce3dc4525e24d\x94K N\x86\x94\x8c\x14run_5c9adcde9c03b8b1\x94K!N\x86\x94\x8c\x14run_5cc032301cb44666\x94K"N\x86\x94\x8c\x14run_41d574d4866a27a1\x94K#N\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh{\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h\x81)}\x94\x8c\x05_name\x94h{sNt\x94bh|h\x7fh\x81\x85\x94R\x94(h\x81)}\x94h\x85h|sNt\x94b\x8c\x14run_583fbeed838cced5\x94h\n\x8c\x14run_28159d44aa267024\x94h\x0b\x8c\x14run_250c26e1ba562237\x94h\x0c\x8c\x14run_12cee40b82354fab\x94h\r\x8c\x14run_d6072f62493cc5af\x94h\x0e\x8c\x14run_39f5beb490ee4833\x94h\x0f\x8c\x14run_610cc1e1311c2792\x94h\x10\x8c\x14run_5061cfcd53f488df\x94h\x11\x8c\x14run_ed2e9ab42cf3819c\x94h\x12\x8c\x14run_d3aa194ff18a9e75\x94h\x13\x8c\x14run_eab37e4b3e032de2\x94h\x14\x8c\x14run_7b17fe71946f4dd7\x94h\x15\x8c\x14run_bd34df1820fd3dd0\x94h\x16\x8c\x14run_cd3179da84da7836\x94h\x17\x8c\x14run_c1d9e06a52efb84d\x94h\x18\x8c\x14run_8ca570a3bee4327e\x94h\x19\x8c\x14run_069cca5a0bbb1937\x94h\x1a\x8c\x14run_8b6552e2914a062f\x94h\x1b\x8c\x14run_babaf70b2b786682\x94h\x1c\x8c\x14run_467c506b6744c831\x94h\x1d\x8c\x14run_58f55feb935887fb\x94h\x1e\x8c\x14run_7d461adf7ab73336\x94h\x1f\x8c\x14run_b97accb0b36736bf\x94h \x8c\x14run_d13fd5c825a5a7e9\x94h!\x8c\x14run_6621b58bd327078d\x94h"\x8c\x14run_2cfb6b191b7a46f2\x94h#\x8c\x14run_ae576072a28ef51e\x94h$\x8c\x14run_b29633ebde708f87\x94h%\x8c\x14run_5450f25d2ed9c22a\x94h&\x8c\x14run_4f62f5b571b6109b\x94h\'\x8c\x14run_195d188bbd583ece\x94h(\x8c\x14run_5b93caea6ecd1712\x94h)\x8c\x14run_5d2ce3dc4525e24d\x94h*\x8c\x14run_5c9adcde9c03b8b1\x94h+\x8c\x14run_5cc032301cb44666\x94h,\x8c\x14run_41d574d4866a27a1\x94h-ub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94(\x8cFdata/processed/review/results/methods/GaMD-native-2000-3-solv_plot.svg\x94\x8cMdata/processed/review/results/methods/GaMD-native-2000-3-solv_properties.json\x94e}\x94(h/}\x94(\x8c\x04plot\x94K\x00N\x86\x94\x8c\x04data\x94K\x01N\x86\x94uhy]\x94(h{h|eh{h\x7fh\x81\x85\x94R\x94(h\x81)}\x94h\x85h{sNt\x94bh|h\x7fh\x81\x85\x94R\x94(h\x81)}\x94h\x85h|sNt\x94bh\xb7h\xb3h\xb9h\xb4ub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94}\x94(h/}\x94hy]\x94(h{h|eh{h\x7fh\x81\x85\x94R\x94(h\x81)}\x94h\x85h{sNt\x94bh|h\x7fh\x81\x85\x94R\x94(h\x81)}\x94h\x85h|sNt\x94bub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94(\x8c\x04GaMD\x94\x8c\x06native\x94\x8c\x042000\x94\x8c\x013\x94e}\x94(h/}\x94(\x8c\x06method\x94K\x00N\x86\x94\x8c\x07solvent\x94K\x01N\x86\x94\x8c\x07simtime\x94K\x02N\x86\x94\x8c\x05igamd\x94K\x03N\x86\x94uhy]\x94(h{h|eh{h\x7fh\x81\x85\x94R\x94(h\x81)}\x94h\x85h{sNt\x94bh|h\x7fh\x81\x85\x94R\x94(h\x81)}\x94h\x85h|sNt\x94b\x8c\x06method\x94h\xd7\x8c\x07solvent\x94h\xd8\x8c\x07simtime\x94h\xd9\x8c\x05igamd\x94h\xdaub\x8c\x07threads\x94K\x02\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x02K\x01\x8c\x04/tmp\x94e}\x94(h/}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uhy]\x94(h{h|eh{h\x7fh\x81\x85\x94R\x94(h\x81)}\x94h\x85h{sNt\x94bh|h\x7fh\x81\x85\x94R\x94(h\x81)}\x94h\x85h|sNt\x94bh\xfaK\x02h\xfcK\x01h\xfeh\xf7ub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8cPdata/processed/review/notebooks/methods/GaMD-native-2000-3-solv_properties.ipynb\x94a}\x94(h/}\x94\x8c\x08notebook\x94K\x00N\x86\x94shy]\x94(h{h|eh{h\x7fh\x81\x85\x94R\x94(h\x81)}\x94h\x85h{sNt\x94bh|h\x7fh\x81\x85\x94R\x94(h\x81)}\x94h\x85h|sNt\x94bj\x10\x01\x00\x00j\r\x01\x00\x00ub\x8c\x06config\x94}\x94(\x8c\x0bthreads_max\x94K\x0c\x8c\x16run_single_md_analysis\x94\x88\x8c\x11run_comp_analysis\x94\x89\x8c\x14run_heatmap_analysis\x94\x89\x8c\x0frun_method_comp\x94\x89\x8c\x0frun_eq_analysis\x94\x89\x8c\trun_omega\x94\x89\x8c\trun_rdkit\x94\x89\x8c\x19run_cheminfo_NOE_analysis\x94\x89\x8c\x12make_paper_figures\x94\x89\x8c\x13update_jupyter_book\x94\x88\x8c\x11convergence_check\x94]\x94\x8c\x10210a1ea8aa678b16\x94a\x8c\x15run_convergence_check\x94\x89\x8c\x0fmethod_defaults\x94}\x94\x8c\x05igamd\x94}\x94(\x8c\x07methods\x94]\x94\x8c\x04GaMD\x94a\x8c\x07default\x94h\xda\x8c\x06others\x94\x8c\x03nan\x94us\x8c\tshortened\x94\x89\x8c\x06stride\x94K\x01\x8c\x04ns_h\x94G@\x1e\x00\x00\x00\x00\x00\x00\x8c\thash_list\x94]\x94(]\x94(\x8c\x1028159d44aa267024\x94\x8c\x105ead922859f5c96d\x94\x8c\x105ead922859f5c96d\x94\x8c\x0255\x94\x8c\x010\x94j@\x01\x00\x00e]\x94(\x8c\x10250c26e1ba562237\x94\x8c\x10eff35c6c3e18f0a3\x94\x8c\x10eff35c6c3e18f0a3\x94\x8c\x0256\x94j@\x01\x00\x00j@\x01\x00\x00e]\x94(\x8c\x10210a1ea8aa678b16\x94\x8c\x103595ce0609206d95\x94\x8c\x10586db4c575bef492\x94\x8c\x0222\x94j@\x01\x00\x00j@\x01\x00\x00e]\x94(\x8c\x10210a1ea8aa678b16\x94\x8c\x10583fbeed838cced5\x94\x8c\x105405e3b785af9601\x94\x8c\x0222\x94j@\x01\x00\x00j@\x01\x00\x00e]\x94(\x8c\x10210a1ea8aa678b16\x94\x8c\x10583fbeed838cced5\x94\x8c\x105405e3b785af9601\x94\x8c\x0222\x94\x8c\x0bomega_basic\x94\x8c\x11rdkit_ETKDGv3mmff\x94e]\x94(\x8c\x10210a1ea8aa678b16\x94\x8c\x10c5389d15c56a3655\x94\x8c\x103a8c4367deb63d6e\x94\x8c\x0222\x94j@\x01\x00\x00j@\x01\x00\x00e]\x94(\x8c\x104f386944d88e6ef8\x94\x8c\x10c99bbf5d17e8efb9\x94\x8c\x10c99bbf5d17e8efb9\x94\x8c\x0224\x94j@\x01\x00\x00j@\x01\x00\x00e]\x94(\x8c\x109e61be229abfc57f\x94\x8c\x1013c5dee00c76dc47\x94\x8c\x1013c5dee00c76dc47\x94\x8c\x0249\x94j@\x01\x00\x00j@\x01\x00\x00ee\x8c\x12confgen_parameters\x94}\x94(\x8c\x05omega\x94]\x94(\x8c\x05basic\x94\x8c\nchloroform\x94\x8c\nlowEwindow\x94\x8c\x0bhighEwindow\x94\x8c\x06lowrms\x94\x8c\x07highrms\x94\x8c\x0bhighmaxconf\x94\x8c\thighmaxit\x94\x8c\x0chighsampling\x94\x8c\rlotsdifferent\x94e\x8c\x05rdkit\x94]\x94(\x8c\x05basic\x94\x8c\x04ETDG\x94\x8c\x07ETKDGv1\x94\x8c\x07ETKDGv2\x94\x8c\x07ETKDGv3\x94\x8c\tsrETKDGv3\x94\x8c\x03KDG\x94\x8c\x08def-ETDG\x94\x8c\x0bdef-ETKDGv1\x94\x8c\x0bdef-ETKDGv2\x94\x8c\x0bdef-ETKDGv3\x94\x8c\rdef-srETKDGv3\x94\x8c\x07def-KDG\x94\x8c\x0chighsampling\x94\x8c\rlotsdifferent\x94eu\x8c\x11heatmap_compounds\x94]\x94(K\x16K\x18K7K8K!K1K2K3e\x8c\x0ccluster_conf\x94}\x94(\x8c\x10242ee4d4af3634ed\x94K\x0f\x8c\x10c5389d15c56a3655\x94K\n\x8c\x103c523c7ca380f925\x94K\n\x8c\x10ca1a37290d9e454e\x94K\x08\x8c\x109a100624325ec4cd\x94K\x06\x8c\x103d00b0964201e088\x94K\n\x8c\x10210a1ea8aa678b16\x94K\x08u\x8c\x08exp_name\x94\x8c\rrefactor-test\x94\x8c\tdata_name\x94\x8c\x1722-02-2021_MacroConf-v2\x94\x8c\x0cdataset_file\x94\x8c3data/external/22-09-2021_MacroConf-v2.1/dataset.csv\x94\x8c\x0bsample_file\x94\x8c\x0bsamples.tsv\x94\x8c\rsample_output\x94\x8c\x0fsamples_old.tsv\x94\x8c\nforcefield\x94\x8c1libs/forcefields/leaprc.protein.ff14SB_noterminal\x94\x8c\x06jb-toc\x94\x8c\x13reports/jb/_toc.yml\x94\x8c\x08jb-links\x94\x8c\x11reports/jb/links/\x94\x8c\x0cDMSO_default\x94\x8c\x0eDMSO_GAFF_RESP\x94\x8c\rCDCl3_default\x94\x8c\nChloroform\x94\x8c\x0bDMSO_params\x94\x8c!libs/md_solvents/dmso/frcmod.dmso\x94\x8c\x08DMSO_box\x94\x8c!libs/md_solvents/dmso/dmsobox.off\x94\x8c\x11Chloroform_params\x94\x8c\x0cfrcmod.chcl3\x94\x8c\x13full_analysis_files\x94]\x94\x8c\x9b../../../data/processed/refactor-test/notebooks/methods/28159d44aa267024-native-586db4c575bef492-native_omega-basic-rdkit-ETKDGv3mmff-NOE_method_comp.ipynb\x94au\x8c\x04rule\x94\x8c\x1bmd_sovlent_props_accumulate\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cG/biggin/b147/univ4859/research/03_macroconf/workflow/rules/../notebooks\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = False; import os; os.chdir(r'/biggin/b147/univ4859/research/03_macroconf/workflow');
######## snakemake preamble end #########

# %%
from src.utils import json_load, json_dump
# start coding here
sasa = {}
psa = {}
for f in snakemake.input:
    id = f.split('/')[4]
    compound_data = json_load(f)
    sasa[id] = compound_data['minimum_sasa']
    psa[id] = compound_data['minimum_psa']

# %%
import matplotlib.pyplot as plt
plt.hist(sasa.values())
plt.xlabel('SASA [nm^2]')
plt.ylabel('No. of compounds')
plt.savefig(snakemake.output.plot, dpi=600)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(psa.values())
plt.xlabel('PSA [nm^2]')
plt.ylabel('No. of simulations')
plt.savefig(snakemake.output.plot, dpi=600)
plt.show()

# %%
results = {'sasa': sasa, 'psa': psa}
json_dump(snakemake.output.data, results)
