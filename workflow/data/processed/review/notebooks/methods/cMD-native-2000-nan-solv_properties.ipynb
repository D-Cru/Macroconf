# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/biggin/b147/univ4859/miniconda3/envs/snakemake/lib/python3.10/site-packages', '/biggin/b147/univ4859/research/03_macroconf/workflow/rules/../notebooks']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95p!\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8cadata/processed/refactor-test/results/55/H2O/cMD/2000/0/5ead922859f5c96d_solvation_properties.json\x94\x8cadata/processed/refactor-test/results/56/H2O/cMD/2000/0/eff35c6c3e18f0a3_solvation_properties.json\x94\x8cadata/processed/refactor-test/results/57/H2O/cMD/2000/0/5dc9eaf6e041f3f2_solvation_properties.json\x94\x8cadata/processed/refactor-test/results/58/H2O/cMD/2000/0/f9df090456539245_solvation_properties.json\x94\x8cadata/processed/refactor-test/results/59/H2O/cMD/2000/0/cc9e4f8eb83eb5e7_solvation_properties.json\x94\x8cadata/processed/refactor-test/results/60/H2O/cMD/2000/0/36cc5f966dea67cb_solvation_properties.json\x94\x8cadata/processed/refactor-test/results/61/H2O/cMD/2000/0/167326bf49040dbd_solvation_properties.json\x94\x8cadata/processed/refactor-test/results/62/H2O/cMD/2000/0/474e13185acfa1a8_solvation_properties.json\x94\x8cadata/processed/refactor-test/results/63/H2O/cMD/2000/0/8db033dcdd7bf626_solvation_properties.json\x94\x8cadata/processed/refactor-test/results/64/H2O/cMD/2000/0/811158a8b531154d_solvation_properties.json\x94\x8cadata/processed/refactor-test/results/65/H2O/cMD/2000/0/45750abf2112f0e2_solvation_properties.json\x94\x8cadata/processed/refactor-test/results/66/H2O/cMD/2000/0/8b69117d53937901_solvation_properties.json\x94\x8cadata/processed/refactor-test/results/68/H2O/cMD/2000/0/11a7fb1e6aad7905_solvation_properties.json\x94\x8cidata/processed/refactor-test/results/1_1/Chloroform/cMD/2000/0/f2825d3690a271d0_solvation_properties.json\x94\x8cmdata/processed/refactor-test/results/1_2/DMSO_GAFF_RESP/cMD/2000/0/421b10c8566b49cb_solvation_properties.json\x94\x8cldata/processed/refactor-test/results/22/DMSO_GAFF_RESP/cMD/2000/0/79804846e6901cf6_solvation_properties.json\x94\x8cldata/processed/refactor-test/results/24/DMSO_GAFF_RESP/cMD/2000/0/2f45361261b805e5_solvation_properties.json\x94\x8cldata/processed/refactor-test/results/27/DMSO_GAFF_RESP/cMD/2000/0/334abba1d29a4378_solvation_properties.json\x94\x8cldata/processed/refactor-test/results/28/DMSO_GAFF_RESP/cMD/2000/0/74633fb83c0d5f89_solvation_properties.json\x94\x8cldata/processed/refactor-test/results/29/DMSO_GAFF_RESP/cMD/2000/0/c4209a995bd14e57_solvation_properties.json\x94\x8cldata/processed/refactor-test/results/30/DMSO_GAFF_RESP/cMD/2000/0/126bbd887309df40_solvation_properties.json\x94\x8cldata/processed/refactor-test/results/31/DMSO_GAFF_RESP/cMD/2000/0/d1d453ef88c14913_solvation_properties.json\x94\x8cldata/processed/refactor-test/results/32/DMSO_GAFF_RESP/cMD/2000/0/fa08f684840cbc89_solvation_properties.json\x94\x8cldata/processed/refactor-test/results/33/DMSO_GAFF_RESP/cMD/2000/0/a03586fd58d627cd_solvation_properties.json\x94\x8cldata/processed/refactor-test/results/35/DMSO_GAFF_RESP/cMD/2000/0/ae86721015402cfa_solvation_properties.json\x94\x8cldata/processed/refactor-test/results/36/DMSO_GAFF_RESP/cMD/2000/0/13607ce653c1715e_solvation_properties.json\x94\x8cldata/processed/refactor-test/results/38/DMSO_GAFF_RESP/cMD/2000/0/439e771e612e69f6_solvation_properties.json\x94\x8cldata/processed/refactor-test/results/39/DMSO_GAFF_RESP/cMD/2000/0/30d5ac208620d9ce_solvation_properties.json\x94\x8cldata/processed/refactor-test/results/40/DMSO_GAFF_RESP/cMD/2000/0/4e7bd481d58354ec_solvation_properties.json\x94\x8cldata/processed/refactor-test/results/41/DMSO_GAFF_RESP/cMD/2000/0/152ec36e3269fbd5_solvation_properties.json\x94\x8cldata/processed/refactor-test/results/42/DMSO_GAFF_RESP/cMD/2000/0/e3a36fd0612b2ce3_solvation_properties.json\x94\x8cldata/processed/refactor-test/results/49/DMSO_GAFF_RESP/cMD/2000/0/b0163eba7e6d9b80_solvation_properties.json\x94\x8cldata/processed/refactor-test/results/50/DMSO_GAFF_RESP/cMD/2000/0/4b93d27539017144_solvation_properties.json\x94\x8cldata/processed/refactor-test/results/51/DMSO_GAFF_RESP/cMD/2000/0/26e5e96f1ec47099_solvation_properties.json\x94\x8cadata/processed/refactor-test/results/52/H2O/cMD/2000/0/777fb4f8db256554_solvation_properties.json\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\x14run_5ead922859f5c96d\x94K\x00N\x86\x94\x8c\x14run_eff35c6c3e18f0a3\x94K\x01N\x86\x94\x8c\x14run_5dc9eaf6e041f3f2\x94K\x02N\x86\x94\x8c\x14run_f9df090456539245\x94K\x03N\x86\x94\x8c\x14run_cc9e4f8eb83eb5e7\x94K\x04N\x86\x94\x8c\x14run_36cc5f966dea67cb\x94K\x05N\x86\x94\x8c\x14run_167326bf49040dbd\x94K\x06N\x86\x94\x8c\x14run_474e13185acfa1a8\x94K\x07N\x86\x94\x8c\x14run_8db033dcdd7bf626\x94K\x08N\x86\x94\x8c\x14run_811158a8b531154d\x94K\tN\x86\x94\x8c\x14run_45750abf2112f0e2\x94K\nN\x86\x94\x8c\x14run_8b69117d53937901\x94K\x0bN\x86\x94\x8c\x14run_11a7fb1e6aad7905\x94K\x0cN\x86\x94\x8c\x14run_f2825d3690a271d0\x94K\rN\x86\x94\x8c\x14run_421b10c8566b49cb\x94K\x0eN\x86\x94\x8c\x14run_79804846e6901cf6\x94K\x0fN\x86\x94\x8c\x14run_2f45361261b805e5\x94K\x10N\x86\x94\x8c\x14run_334abba1d29a4378\x94K\x11N\x86\x94\x8c\x14run_74633fb83c0d5f89\x94K\x12N\x86\x94\x8c\x14run_c4209a995bd14e57\x94K\x13N\x86\x94\x8c\x14run_126bbd887309df40\x94K\x14N\x86\x94\x8c\x14run_d1d453ef88c14913\x94K\x15N\x86\x94\x8c\x14run_fa08f684840cbc89\x94K\x16N\x86\x94\x8c\x14run_a03586fd58d627cd\x94K\x17N\x86\x94\x8c\x14run_ae86721015402cfa\x94K\x18N\x86\x94\x8c\x14run_13607ce653c1715e\x94K\x19N\x86\x94\x8c\x14run_439e771e612e69f6\x94K\x1aN\x86\x94\x8c\x14run_30d5ac208620d9ce\x94K\x1bN\x86\x94\x8c\x14run_4e7bd481d58354ec\x94K\x1cN\x86\x94\x8c\x14run_152ec36e3269fbd5\x94K\x1dN\x86\x94\x8c\x14run_e3a36fd0612b2ce3\x94K\x1eN\x86\x94\x8c\x14run_b0163eba7e6d9b80\x94K\x1fN\x86\x94\x8c\x14run_4b93d27539017144\x94K N\x86\x94\x8c\x14run_26e5e96f1ec47099\x94K!N\x86\x94\x8c\x14run_777fb4f8db256554\x94K"N\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94ehx\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h~)}\x94\x8c\x05_name\x94hxsNt\x94bhyh|h~\x85\x94R\x94(h~)}\x94h\x82hysNt\x94bh0h\nh2h\x0bh4h\x0ch6h\rh8h\x0eh:h\x0fh<h\x10h>h\x11h@h\x12hBh\x13hDh\x14hFh\x15hHh\x16hJh\x17hLh\x18hNh\x19hPh\x1ahRh\x1bhTh\x1chVh\x1dhXh\x1ehZh\x1fh\\h h^h!h`h"hbh#hdh$hfh%hhh&hjh\'hlh(hnh)hph*hrh+hth,ub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94(\x8cGdata/processed/review/results/methods/cMD-native-2000-nan-solv_plot.svg\x94\x8cNdata/processed/review/results/methods/cMD-native-2000-nan-solv_properties.json\x94e}\x94(h.}\x94(\x8c\x04plot\x94K\x00N\x86\x94\x8c\x04data\x94K\x01N\x86\x94uhv]\x94(hxhyehxh|h~\x85\x94R\x94(h~)}\x94h\x82hxsNt\x94bhyh|h~\x85\x94R\x94(h~)}\x94h\x82hysNt\x94bh\x90h\x8ch\x92h\x8dub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94}\x94(h.}\x94hv]\x94(hxhyehxh|h~\x85\x94R\x94(h~)}\x94h\x82hxsNt\x94bhyh|h~\x85\x94R\x94(h~)}\x94h\x82hysNt\x94bub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94(\x8c\x03cMD\x94\x8c\x06native\x94\x8c\x042000\x94\x8c\x03nan\x94e}\x94(h.}\x94(\x8c\x06method\x94K\x00N\x86\x94\x8c\x07solvent\x94K\x01N\x86\x94\x8c\x07simtime\x94K\x02N\x86\x94\x8c\x05igamd\x94K\x03N\x86\x94uhv]\x94(hxhyehxh|h~\x85\x94R\x94(h~)}\x94h\x82hxsNt\x94bhyh|h~\x85\x94R\x94(h~)}\x94h\x82hysNt\x94b\x8c\x06method\x94h\xb0\x8c\x07solvent\x94h\xb1\x8c\x07simtime\x94h\xb2\x8c\x05igamd\x94h\xb3ub\x8c\x07threads\x94K\x02\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x02K\x01\x8c\x04/tmp\x94e}\x94(h.}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uhv]\x94(hxhyehxh|h~\x85\x94R\x94(h~)}\x94h\x82hxsNt\x94bhyh|h~\x85\x94R\x94(h~)}\x94h\x82hysNt\x94bh\xd3K\x02h\xd5K\x01h\xd7h\xd0ub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8cQdata/processed/review/notebooks/methods/cMD-native-2000-nan-solv_properties.ipynb\x94a}\x94(h.}\x94\x8c\x08notebook\x94K\x00N\x86\x94shv]\x94(hxhyehxh|h~\x85\x94R\x94(h~)}\x94h\x82hxsNt\x94bhyh|h~\x85\x94R\x94(h~)}\x94h\x82hysNt\x94bh\xe9h\xe6ub\x8c\x06config\x94}\x94(\x8c\x0bthreads_max\x94K\x0c\x8c\x16run_single_md_analysis\x94\x88\x8c\x11run_comp_analysis\x94\x89\x8c\x14run_heatmap_analysis\x94\x89\x8c\x0frun_method_comp\x94\x89\x8c\x0frun_eq_analysis\x94\x89\x8c\trun_omega\x94\x89\x8c\trun_rdkit\x94\x89\x8c\x19run_cheminfo_NOE_analysis\x94\x89\x8c\x12make_paper_figures\x94\x89\x8c\x13update_jupyter_book\x94\x88\x8c\x11convergence_check\x94]\x94\x8c\x10210a1ea8aa678b16\x94a\x8c\x15run_convergence_check\x94\x89\x8c\x0fmethod_defaults\x94}\x94\x8c\x05igamd\x94}\x94(\x8c\x07methods\x94]\x94\x8c\x04GaMD\x94a\x8c\x07default\x94\x8c\x013\x94\x8c\x06others\x94\x8c\x03nan\x94us\x8c\tshortened\x94\x89\x8c\x06stride\x94K\x01\x8c\x04ns_h\x94G@\x1e\x00\x00\x00\x00\x00\x00\x8c\thash_list\x94]\x94(]\x94(\x8c\x1028159d44aa267024\x94\x8c\x105ead922859f5c96d\x94\x8c\x105ead922859f5c96d\x94\x8c\x0255\x94\x8c\x010\x94j\x1a\x01\x00\x00e]\x94(\x8c\x10250c26e1ba562237\x94\x8c\x10eff35c6c3e18f0a3\x94\x8c\x10eff35c6c3e18f0a3\x94\x8c\x0256\x94j\x1a\x01\x00\x00j\x1a\x01\x00\x00e]\x94(\x8c\x10210a1ea8aa678b16\x94\x8c\x103595ce0609206d95\x94\x8c\x10586db4c575bef492\x94\x8c\x0222\x94j\x1a\x01\x00\x00j\x1a\x01\x00\x00e]\x94(\x8c\x10210a1ea8aa678b16\x94\x8c\x10583fbeed838cced5\x94\x8c\x105405e3b785af9601\x94\x8c\x0222\x94j\x1a\x01\x00\x00j\x1a\x01\x00\x00e]\x94(\x8c\x10210a1ea8aa678b16\x94\x8c\x10583fbeed838cced5\x94\x8c\x105405e3b785af9601\x94\x8c\x0222\x94\x8c\x0bomega_basic\x94\x8c\x11rdkit_ETKDGv3mmff\x94e]\x94(\x8c\x10210a1ea8aa678b16\x94\x8c\x10c5389d15c56a3655\x94\x8c\x103a8c4367deb63d6e\x94\x8c\x0222\x94j\x1a\x01\x00\x00j\x1a\x01\x00\x00e]\x94(\x8c\x104f386944d88e6ef8\x94\x8c\x10c99bbf5d17e8efb9\x94\x8c\x10c99bbf5d17e8efb9\x94\x8c\x0224\x94j\x1a\x01\x00\x00j\x1a\x01\x00\x00e]\x94(\x8c\x109e61be229abfc57f\x94\x8c\x1013c5dee00c76dc47\x94\x8c\x1013c5dee00c76dc47\x94\x8c\x0249\x94j\x1a\x01\x00\x00j\x1a\x01\x00\x00ee\x8c\x12confgen_parameters\x94}\x94(\x8c\x05omega\x94]\x94(\x8c\x05basic\x94\x8c\nchloroform\x94\x8c\nlowEwindow\x94\x8c\x0bhighEwindow\x94\x8c\x06lowrms\x94\x8c\x07highrms\x94\x8c\x0bhighmaxconf\x94\x8c\thighmaxit\x94\x8c\x0chighsampling\x94\x8c\rlotsdifferent\x94e\x8c\x05rdkit\x94]\x94(\x8c\x05basic\x94\x8c\x04ETDG\x94\x8c\x07ETKDGv1\x94\x8c\x07ETKDGv2\x94\x8c\x07ETKDGv3\x94\x8c\tsrETKDGv3\x94\x8c\x03KDG\x94\x8c\x08def-ETDG\x94\x8c\x0bdef-ETKDGv1\x94\x8c\x0bdef-ETKDGv2\x94\x8c\x0bdef-ETKDGv3\x94\x8c\rdef-srETKDGv3\x94\x8c\x07def-KDG\x94\x8c\x0chighsampling\x94\x8c\rlotsdifferent\x94eu\x8c\x11heatmap_compounds\x94]\x94(K\x16K\x18K7K8K!K1K2K3e\x8c\x0ccluster_conf\x94}\x94(\x8c\x10242ee4d4af3634ed\x94K\x0f\x8c\x10c5389d15c56a3655\x94K\n\x8c\x103c523c7ca380f925\x94K\n\x8c\x10ca1a37290d9e454e\x94K\x08\x8c\x109a100624325ec4cd\x94K\x06\x8c\x103d00b0964201e088\x94K\n\x8c\x10210a1ea8aa678b16\x94K\x08u\x8c\x08exp_name\x94\x8c\rrefactor-test\x94\x8c\tdata_name\x94\x8c\x1722-02-2021_MacroConf-v2\x94\x8c\x0cdataset_file\x94\x8c3data/external/22-09-2021_MacroConf-v2.1/dataset.csv\x94\x8c\x0bsample_file\x94\x8c\x0bsamples.tsv\x94\x8c\rsample_output\x94\x8c\x0fsamples_old.tsv\x94\x8c\nforcefield\x94\x8c1libs/forcefields/leaprc.protein.ff14SB_noterminal\x94\x8c\x06jb-toc\x94\x8c\x13reports/jb/_toc.yml\x94\x8c\x08jb-links\x94\x8c\x11reports/jb/links/\x94\x8c\x0cDMSO_default\x94\x8c\x0eDMSO_GAFF_RESP\x94\x8c\rCDCl3_default\x94\x8c\nChloroform\x94\x8c\x0bDMSO_params\x94\x8c!libs/md_solvents/dmso/frcmod.dmso\x94\x8c\x08DMSO_box\x94\x8c!libs/md_solvents/dmso/dmsobox.off\x94\x8c\x11Chloroform_params\x94\x8c\x0cfrcmod.chcl3\x94\x8c\x13full_analysis_files\x94]\x94\x8c\x9b../../../data/processed/refactor-test/notebooks/methods/28159d44aa267024-native-586db4c575bef492-native_omega-basic-rdkit-ETKDGv3mmff-NOE_method_comp.ipynb\x94au\x8c\x04rule\x94\x8c\x1bmd_sovlent_props_accumulate\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cG/biggin/b147/univ4859/research/03_macroconf/workflow/rules/../notebooks\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = False; import os; os.chdir(r'/biggin/b147/univ4859/research/03_macroconf/workflow');
######## snakemake preamble end #########

# %%
from src.utils import json_load, json_dump
# start coding here
sasa = {}
psa = {}
for f in snakemake.input:
    id = f.split('/')[4]
    compound_data = json_load(f)
    sasa[id] = compound_data['minimum_sasa']
    psa[id] = compound_data['minimum_psa']

# %%
import matplotlib.pyplot as plt
plt.hist(sasa.values())
plt.xlabel('SASA [nm^2]')
plt.ylabel('No. of compounds')
plt.savefig(snakemake.output.plot, dpi=600)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(psa.values())
plt.xlabel('PSA [nm^2]')
plt.ylabel('No. of simulations')
plt.savefig(snakemake.output.plot, dpi=600)
plt.show()

# %%
results = {'sasa': sasa, 'psa': psa}
json_dump(snakemake.output.data, results)
