# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/biggin/b147/univ4859/miniconda3/envs/snakemake/lib/python3.10/site-packages', '/biggin/b147/univ4859/research/03_macroconf/workflow/rules/../notebooks']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95\xc2+\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8cLdata/processed/refactor-test/results/40/conf_gen/rdkit/ETKDGv3mmff/sasa.json\x94\x8cKdata/processed/refactor-test/results/40/conf_gen/rdkit/ETKDGv3mmff/psa.json\x94\x8cLdata/processed/refactor-test/results/38/conf_gen/rdkit/ETKDGv3mmff/sasa.json\x94\x8cKdata/processed/refactor-test/results/38/conf_gen/rdkit/ETKDGv3mmff/psa.json\x94\x8cMdata/processed/refactor-test/results/1_2/conf_gen/rdkit/ETKDGv3mmff/sasa.json\x94\x8cLdata/processed/refactor-test/results/1_2/conf_gen/rdkit/ETKDGv3mmff/psa.json\x94\x8cLdata/processed/refactor-test/results/42/conf_gen/rdkit/ETKDGv3mmff/sasa.json\x94\x8cKdata/processed/refactor-test/results/42/conf_gen/rdkit/ETKDGv3mmff/psa.json\x94\x8cLdata/processed/refactor-test/results/22/conf_gen/rdkit/ETKDGv3mmff/sasa.json\x94\x8cKdata/processed/refactor-test/results/22/conf_gen/rdkit/ETKDGv3mmff/psa.json\x94\x8cLdata/processed/refactor-test/results/57/conf_gen/rdkit/ETKDGv3mmff/sasa.json\x94\x8cKdata/processed/refactor-test/results/57/conf_gen/rdkit/ETKDGv3mmff/psa.json\x94\x8cLdata/processed/refactor-test/results/55/conf_gen/rdkit/ETKDGv3mmff/sasa.json\x94\x8cKdata/processed/refactor-test/results/55/conf_gen/rdkit/ETKDGv3mmff/psa.json\x94\x8cLdata/processed/refactor-test/results/49/conf_gen/rdkit/ETKDGv3mmff/sasa.json\x94\x8cKdata/processed/refactor-test/results/49/conf_gen/rdkit/ETKDGv3mmff/psa.json\x94\x8cLdata/processed/refactor-test/results/33/conf_gen/rdkit/ETKDGv3mmff/sasa.json\x94\x8cKdata/processed/refactor-test/results/33/conf_gen/rdkit/ETKDGv3mmff/psa.json\x94\x8cLdata/processed/refactor-test/results/65/conf_gen/rdkit/ETKDGv3mmff/sasa.json\x94\x8cKdata/processed/refactor-test/results/65/conf_gen/rdkit/ETKDGv3mmff/psa.json\x94\x8cLdata/processed/refactor-test/results/36/conf_gen/rdkit/ETKDGv3mmff/sasa.json\x94\x8cKdata/processed/refactor-test/results/36/conf_gen/rdkit/ETKDGv3mmff/psa.json\x94\x8cLdata/processed/refactor-test/results/60/conf_gen/rdkit/ETKDGv3mmff/sasa.json\x94\x8cKdata/processed/refactor-test/results/60/conf_gen/rdkit/ETKDGv3mmff/psa.json\x94\x8cLdata/processed/refactor-test/results/39/conf_gen/rdkit/ETKDGv3mmff/sasa.json\x94\x8cKdata/processed/refactor-test/results/39/conf_gen/rdkit/ETKDGv3mmff/psa.json\x94\x8cLdata/processed/refactor-test/results/31/conf_gen/rdkit/ETKDGv3mmff/sasa.json\x94\x8cKdata/processed/refactor-test/results/31/conf_gen/rdkit/ETKDGv3mmff/psa.json\x94\x8cLdata/processed/refactor-test/results/62/conf_gen/rdkit/ETKDGv3mmff/sasa.json\x94\x8cKdata/processed/refactor-test/results/62/conf_gen/rdkit/ETKDGv3mmff/psa.json\x94\x8cLdata/processed/refactor-test/results/64/conf_gen/rdkit/ETKDGv3mmff/sasa.json\x94\x8cKdata/processed/refactor-test/results/64/conf_gen/rdkit/ETKDGv3mmff/psa.json\x94\x8cLdata/processed/refactor-test/results/52/conf_gen/rdkit/ETKDGv3mmff/sasa.json\x94\x8cKdata/processed/refactor-test/results/52/conf_gen/rdkit/ETKDGv3mmff/psa.json\x94\x8cLdata/processed/refactor-test/results/68/conf_gen/rdkit/ETKDGv3mmff/sasa.json\x94\x8cKdata/processed/refactor-test/results/68/conf_gen/rdkit/ETKDGv3mmff/psa.json\x94\x8cLdata/processed/refactor-test/results/24/conf_gen/rdkit/ETKDGv3mmff/sasa.json\x94\x8cKdata/processed/refactor-test/results/24/conf_gen/rdkit/ETKDGv3mmff/psa.json\x94\x8cLdata/processed/refactor-test/results/56/conf_gen/rdkit/ETKDGv3mmff/sasa.json\x94\x8cKdata/processed/refactor-test/results/56/conf_gen/rdkit/ETKDGv3mmff/psa.json\x94\x8cLdata/processed/refactor-test/results/59/conf_gen/rdkit/ETKDGv3mmff/sasa.json\x94\x8cKdata/processed/refactor-test/results/59/conf_gen/rdkit/ETKDGv3mmff/psa.json\x94\x8cLdata/processed/refactor-test/results/41/conf_gen/rdkit/ETKDGv3mmff/sasa.json\x94\x8cKdata/processed/refactor-test/results/41/conf_gen/rdkit/ETKDGv3mmff/psa.json\x94\x8cLdata/processed/refactor-test/results/32/conf_gen/rdkit/ETKDGv3mmff/sasa.json\x94\x8cKdata/processed/refactor-test/results/32/conf_gen/rdkit/ETKDGv3mmff/psa.json\x94\x8cLdata/processed/refactor-test/results/61/conf_gen/rdkit/ETKDGv3mmff/sasa.json\x94\x8cKdata/processed/refactor-test/results/61/conf_gen/rdkit/ETKDGv3mmff/psa.json\x94\x8cLdata/processed/refactor-test/results/66/conf_gen/rdkit/ETKDGv3mmff/sasa.json\x94\x8cKdata/processed/refactor-test/results/66/conf_gen/rdkit/ETKDGv3mmff/psa.json\x94\x8cLdata/processed/refactor-test/results/51/conf_gen/rdkit/ETKDGv3mmff/sasa.json\x94\x8cKdata/processed/refactor-test/results/51/conf_gen/rdkit/ETKDGv3mmff/psa.json\x94\x8cLdata/processed/refactor-test/results/30/conf_gen/rdkit/ETKDGv3mmff/sasa.json\x94\x8cKdata/processed/refactor-test/results/30/conf_gen/rdkit/ETKDGv3mmff/psa.json\x94\x8cLdata/processed/refactor-test/results/35/conf_gen/rdkit/ETKDGv3mmff/sasa.json\x94\x8cKdata/processed/refactor-test/results/35/conf_gen/rdkit/ETKDGv3mmff/psa.json\x94\x8cLdata/processed/refactor-test/results/29/conf_gen/rdkit/ETKDGv3mmff/sasa.json\x94\x8cKdata/processed/refactor-test/results/29/conf_gen/rdkit/ETKDGv3mmff/psa.json\x94\x8cLdata/processed/refactor-test/results/27/conf_gen/rdkit/ETKDGv3mmff/sasa.json\x94\x8cKdata/processed/refactor-test/results/27/conf_gen/rdkit/ETKDGv3mmff/psa.json\x94\x8cLdata/processed/refactor-test/results/28/conf_gen/rdkit/ETKDGv3mmff/sasa.json\x94\x8cKdata/processed/refactor-test/results/28/conf_gen/rdkit/ETKDGv3mmff/psa.json\x94\x8cLdata/processed/refactor-test/results/50/conf_gen/rdkit/ETKDGv3mmff/sasa.json\x94\x8cKdata/processed/refactor-test/results/50/conf_gen/rdkit/ETKDGv3mmff/psa.json\x94\x8cLdata/processed/refactor-test/results/58/conf_gen/rdkit/ETKDGv3mmff/sasa.json\x94\x8cKdata/processed/refactor-test/results/58/conf_gen/rdkit/ETKDGv3mmff/psa.json\x94\x8cMdata/processed/refactor-test/results/1_1/conf_gen/rdkit/ETKDGv3mmff/sasa.json\x94\x8cLdata/processed/refactor-test/results/1_1/conf_gen/rdkit/ETKDGv3mmff/psa.json\x94\x8cLdata/processed/refactor-test/results/63/conf_gen/rdkit/ETKDGv3mmff/sasa.json\x94\x8cKdata/processed/refactor-test/results/63/conf_gen/rdkit/ETKDGv3mmff/psa.json\x94\x8cMdata/processed/review/results/methods/GaMD-native-2000-3-solv_properties.json\x94\x8cNdata/processed/review/results/methods/cMD-native-2000-nan-solv_properties.json\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\x0740-sasa\x94K\x00N\x86\x94\x8c\x0640-psa\x94K\x01N\x86\x94\x8c\x0738-sasa\x94K\x02N\x86\x94\x8c\x0638-psa\x94K\x03N\x86\x94\x8c\x081_2-sasa\x94K\x04N\x86\x94\x8c\x071_2-psa\x94K\x05N\x86\x94\x8c\x0742-sasa\x94K\x06N\x86\x94\x8c\x0642-psa\x94K\x07N\x86\x94\x8c\x0722-sasa\x94K\x08N\x86\x94\x8c\x0622-psa\x94K\tN\x86\x94\x8c\x0757-sasa\x94K\nN\x86\x94\x8c\x0657-psa\x94K\x0bN\x86\x94\x8c\x0755-sasa\x94K\x0cN\x86\x94\x8c\x0655-psa\x94K\rN\x86\x94\x8c\x0749-sasa\x94K\x0eN\x86\x94\x8c\x0649-psa\x94K\x0fN\x86\x94\x8c\x0733-sasa\x94K\x10N\x86\x94\x8c\x0633-psa\x94K\x11N\x86\x94\x8c\x0765-sasa\x94K\x12N\x86\x94\x8c\x0665-psa\x94K\x13N\x86\x94\x8c\x0736-sasa\x94K\x14N\x86\x94\x8c\x0636-psa\x94K\x15N\x86\x94\x8c\x0760-sasa\x94K\x16N\x86\x94\x8c\x0660-psa\x94K\x17N\x86\x94\x8c\x0739-sasa\x94K\x18N\x86\x94\x8c\x0639-psa\x94K\x19N\x86\x94\x8c\x0731-sasa\x94K\x1aN\x86\x94\x8c\x0631-psa\x94K\x1bN\x86\x94\x8c\x0762-sasa\x94K\x1cN\x86\x94\x8c\x0662-psa\x94K\x1dN\x86\x94\x8c\x0764-sasa\x94K\x1eN\x86\x94\x8c\x0664-psa\x94K\x1fN\x86\x94\x8c\x0752-sasa\x94K N\x86\x94\x8c\x0652-psa\x94K!N\x86\x94\x8c\x0768-sasa\x94K"N\x86\x94\x8c\x0668-psa\x94K#N\x86\x94\x8c\x0724-sasa\x94K$N\x86\x94\x8c\x0624-psa\x94K%N\x86\x94\x8c\x0756-sasa\x94K&N\x86\x94\x8c\x0656-psa\x94K\'N\x86\x94\x8c\x0759-sasa\x94K(N\x86\x94\x8c\x0659-psa\x94K)N\x86\x94\x8c\x0741-sasa\x94K*N\x86\x94\x8c\x0641-psa\x94K+N\x86\x94\x8c\x0732-sasa\x94K,N\x86\x94\x8c\x0632-psa\x94K-N\x86\x94\x8c\x0761-sasa\x94K.N\x86\x94\x8c\x0661-psa\x94K/N\x86\x94\x8c\x0766-sasa\x94K0N\x86\x94\x8c\x0666-psa\x94K1N\x86\x94\x8c\x0751-sasa\x94K2N\x86\x94\x8c\x0651-psa\x94K3N\x86\x94\x8c\x0730-sasa\x94K4N\x86\x94\x8c\x0630-psa\x94K5N\x86\x94\x8c\x0735-sasa\x94K6N\x86\x94\x8c\x0635-psa\x94K7N\x86\x94\x8c\x0729-sasa\x94K8N\x86\x94\x8c\x0629-psa\x94K9N\x86\x94\x8c\x0727-sasa\x94K:N\x86\x94\x8c\x0627-psa\x94K;N\x86\x94\x8c\x0728-sasa\x94K<N\x86\x94\x8c\x0628-psa\x94K=N\x86\x94\x8c\x0750-sasa\x94K>N\x86\x94\x8c\x0650-psa\x94K?N\x86\x94\x8c\x0758-sasa\x94K@N\x86\x94\x8c\x0658-psa\x94KAN\x86\x94\x8c\x081_1-sasa\x94KBN\x86\x94\x8c\x071_1-psa\x94KCN\x86\x94\x8c\x0763-sasa\x94KDN\x86\x94\x8c\x0663-psa\x94KEN\x86\x94\x8c\x04gamd\x94KFN\x86\x94\x8c\x03cmd\x94KGN\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\xe7\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h\xed)}\x94\x8c\x05_name\x94h\xe7sNt\x94bh\xe8h\xebh\xed\x85\x94R\x94(h\xed)}\x94h\xf1h\xe8sNt\x94b\x8c\x0740-sasa\x94h\n\x8c\x0640-psa\x94h\x0b\x8c\x0738-sasa\x94h\x0c\x8c\x0638-psa\x94h\r\x8c\x081_2-sasa\x94h\x0e\x8c\x071_2-psa\x94h\x0f\x8c\x0742-sasa\x94h\x10\x8c\x0642-psa\x94h\x11\x8c\x0722-sasa\x94h\x12\x8c\x0622-psa\x94h\x13\x8c\x0757-sasa\x94h\x14\x8c\x0657-psa\x94h\x15\x8c\x0755-sasa\x94h\x16\x8c\x0655-psa\x94h\x17\x8c\x0749-sasa\x94h\x18\x8c\x0649-psa\x94h\x19\x8c\x0733-sasa\x94h\x1a\x8c\x0633-psa\x94h\x1b\x8c\x0765-sasa\x94h\x1c\x8c\x0665-psa\x94h\x1d\x8c\x0736-sasa\x94h\x1e\x8c\x0636-psa\x94h\x1f\x8c\x0760-sasa\x94h \x8c\x0660-psa\x94h!\x8c\x0739-sasa\x94h"\x8c\x0639-psa\x94h#\x8c\x0731-sasa\x94h$\x8c\x0631-psa\x94h%\x8c\x0762-sasa\x94h&\x8c\x0662-psa\x94h\'\x8c\x0764-sasa\x94h(\x8c\x0664-psa\x94h)\x8c\x0752-sasa\x94h*\x8c\x0652-psa\x94h+\x8c\x0768-sasa\x94h,\x8c\x0668-psa\x94h-\x8c\x0724-sasa\x94h.\x8c\x0624-psa\x94h/\x8c\x0756-sasa\x94h0\x8c\x0656-psa\x94h1\x8c\x0759-sasa\x94h2\x8c\x0659-psa\x94h3\x8c\x0741-sasa\x94h4\x8c\x0641-psa\x94h5\x8c\x0732-sasa\x94h6\x8c\x0632-psa\x94h7\x8c\x0761-sasa\x94h8\x8c\x0661-psa\x94h9\x8c\x0766-sasa\x94h:\x8c\x0666-psa\x94h;\x8c\x0751-sasa\x94h<\x8c\x0651-psa\x94h=\x8c\x0730-sasa\x94h>\x8c\x0630-psa\x94h?\x8c\x0735-sasa\x94h@\x8c\x0635-psa\x94hA\x8c\x0729-sasa\x94hB\x8c\x0629-psa\x94hC\x8c\x0727-sasa\x94hD\x8c\x0627-psa\x94hE\x8c\x0728-sasa\x94hF\x8c\x0628-psa\x94hG\x8c\x0750-sasa\x94hH\x8c\x0650-psa\x94hI\x8c\x0758-sasa\x94hJ\x8c\x0658-psa\x94hK\x8c\x081_1-sasa\x94hL\x8c\x071_1-psa\x94hM\x8c\x0763-sasa\x94hN\x8c\x0663-psa\x94hOh\xe1hPh\xe3hQub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94(\x8cJdata/processed/review/results/methods/rdkit-ETKDGv3mmff-solv-sasa_plot.svg\x94\x8cIdata/processed/review/results/methods/rdkit-ETKDGv3mmff-solv-psa_plot.svg\x94e}\x94(hS}\x94(\x8c\tplot_sasa\x94K\x00N\x86\x94\x8c\x08plot_psa\x94K\x01N\x86\x94uh\xe5]\x94(h\xe7h\xe8eh\xe7h\xebh\xed\x85\x94R\x94(h\xed)}\x94h\xf1h\xe7sNt\x94bh\xe8h\xebh\xed\x85\x94R\x94(h\xed)}\x94h\xf1h\xe8sNt\x94bjE\x01\x00\x00jA\x01\x00\x00jG\x01\x00\x00jB\x01\x00\x00ub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94}\x94(hS}\x94h\xe5]\x94(h\xe7h\xe8eh\xe7h\xebh\xed\x85\x94R\x94(h\xed)}\x94h\xf1h\xe7sNt\x94bh\xe8h\xebh\xed\x85\x94R\x94(h\xed)}\x94h\xf1h\xe8sNt\x94bub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94(\x8c\x05rdkit\x94\x8c\x0bETKDGv3mmff\x94e}\x94(hS}\x94(\x8c\x07confgen\x94K\x00N\x86\x94\x8c\x04mode\x94K\x01N\x86\x94uh\xe5]\x94(h\xe7h\xe8eh\xe7h\xebh\xed\x85\x94R\x94(h\xed)}\x94h\xf1h\xe7sNt\x94bh\xe8h\xebh\xed\x85\x94R\x94(h\xed)}\x94h\xf1h\xe8sNt\x94b\x8c\x07confgen\x94je\x01\x00\x00\x8c\x04mode\x94jf\x01\x00\x00ub\x8c\x07threads\x94K\x02\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x02K\x01\x8c\x04/tmp\x94e}\x94(hS}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh\xe5]\x94(h\xe7h\xe8eh\xe7h\xebh\xed\x85\x94R\x94(h\xed)}\x94h\xf1h\xe7sNt\x94bh\xe8h\xebh\xed\x85\x94R\x94(h\xed)}\x94h\xf1h\xe8sNt\x94bj\x80\x01\x00\x00K\x02j\x82\x01\x00\x00K\x01j\x84\x01\x00\x00j}\x01\x00\x00ub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8cOdata/processed/review/notebooks/methods/rdkit-ETKDGv3mmff-solv_properties.ipynb\x94a}\x94(hS}\x94\x8c\x08notebook\x94K\x00N\x86\x94sh\xe5]\x94(h\xe7h\xe8eh\xe7h\xebh\xed\x85\x94R\x94(h\xed)}\x94h\xf1h\xe7sNt\x94bh\xe8h\xebh\xed\x85\x94R\x94(h\xed)}\x94h\xf1h\xe8sNt\x94bj\x96\x01\x00\x00j\x93\x01\x00\x00ub\x8c\x06config\x94}\x94(\x8c\x0bthreads_max\x94K\x0c\x8c\x16run_single_md_analysis\x94\x89\x8c\x11run_comp_analysis\x94\x89\x8c\x14run_heatmap_analysis\x94\x89\x8c\x0frun_method_comp\x94\x89\x8c\x0frun_eq_analysis\x94\x89\x8c\trun_omega\x94\x89\x8c\trun_rdkit\x94\x89\x8c\x19run_cheminfo_NOE_analysis\x94\x89\x8c\x12make_paper_figures\x94\x88\x8c\x13update_jupyter_book\x94\x88\x8c\x11convergence_check\x94]\x94\x8c\x10210a1ea8aa678b16\x94a\x8c\x15run_convergence_check\x94\x89\x8c\x0fmethod_defaults\x94}\x94\x8c\x05igamd\x94}\x94(\x8c\x07methods\x94]\x94\x8c\x04GaMD\x94a\x8c\x07default\x94\x8c\x013\x94\x8c\x06others\x94\x8c\x03nan\x94us\x8c\tshortened\x94\x89\x8c\x06stride\x94K\x01\x8c\x04ns_h\x94G@\x1e\x00\x00\x00\x00\x00\x00\x8c\thash_list\x94]\x94(]\x94(\x8c\x1028159d44aa267024\x94\x8c\x105ead922859f5c96d\x94\x8c\x105ead922859f5c96d\x94\x8c\x0255\x94\x8c\x010\x94j\xc7\x01\x00\x00e]\x94(\x8c\x10250c26e1ba562237\x94\x8c\x10eff35c6c3e18f0a3\x94\x8c\x10eff35c6c3e18f0a3\x94\x8c\x0256\x94j\xc7\x01\x00\x00j\xc7\x01\x00\x00e]\x94(\x8c\x10210a1ea8aa678b16\x94\x8c\x103595ce0609206d95\x94\x8c\x10586db4c575bef492\x94\x8c\x0222\x94j\xc7\x01\x00\x00j\xc7\x01\x00\x00e]\x94(\x8c\x10210a1ea8aa678b16\x94\x8c\x10583fbeed838cced5\x94\x8c\x105405e3b785af9601\x94\x8c\x0222\x94j\xc7\x01\x00\x00j\xc7\x01\x00\x00e]\x94(\x8c\x10210a1ea8aa678b16\x94\x8c\x10583fbeed838cced5\x94\x8c\x105405e3b785af9601\x94\x8c\x0222\x94\x8c\x0bomega_basic\x94\x8c\x11rdkit_ETKDGv3mmff\x94e]\x94(\x8c\x10210a1ea8aa678b16\x94\x8c\x10c5389d15c56a3655\x94\x8c\x103a8c4367deb63d6e\x94\x8c\x0222\x94j\xc7\x01\x00\x00j\xc7\x01\x00\x00e]\x94(\x8c\x104f386944d88e6ef8\x94\x8c\x10c99bbf5d17e8efb9\x94\x8c\x10c99bbf5d17e8efb9\x94\x8c\x0224\x94j\xc7\x01\x00\x00j\xc7\x01\x00\x00e]\x94(\x8c\x109e61be229abfc57f\x94\x8c\x1013c5dee00c76dc47\x94\x8c\x1013c5dee00c76dc47\x94\x8c\x0249\x94j\xc7\x01\x00\x00j\xc7\x01\x00\x00ee\x8c\x12confgen_parameters\x94}\x94(\x8c\x05omega\x94]\x94(\x8c\x05basic\x94\x8c\nchloroform\x94\x8c\nlowEwindow\x94\x8c\x0bhighEwindow\x94\x8c\x06lowrms\x94\x8c\x07highrms\x94\x8c\x0bhighmaxconf\x94\x8c\thighmaxit\x94\x8c\x0chighsampling\x94\x8c\rlotsdifferent\x94e\x8c\x05rdkit\x94]\x94(\x8c\x05basic\x94\x8c\x04ETDG\x94\x8c\x07ETKDGv1\x94\x8c\x07ETKDGv2\x94\x8c\x07ETKDGv3\x94\x8c\tsrETKDGv3\x94\x8c\x03KDG\x94\x8c\x08def-ETDG\x94\x8c\x0bdef-ETKDGv1\x94\x8c\x0bdef-ETKDGv2\x94\x8c\x0bdef-ETKDGv3\x94\x8c\rdef-srETKDGv3\x94\x8c\x07def-KDG\x94\x8c\x0chighsampling\x94\x8c\rlotsdifferent\x94eu\x8c\x11heatmap_compounds\x94]\x94(K\x16K\x18K7K8K!K1K2K3e\x8c\x0ccluster_conf\x94}\x94(\x8c\x10242ee4d4af3634ed\x94K\x0f\x8c\x10c5389d15c56a3655\x94K\n\x8c\x103c523c7ca380f925\x94K\n\x8c\x10ca1a37290d9e454e\x94K\x08\x8c\x109a100624325ec4cd\x94K\x06\x8c\x103d00b0964201e088\x94K\n\x8c\x10210a1ea8aa678b16\x94K\x08u\x8c\x08exp_name\x94\x8c\rrefactor-test\x94\x8c\tdata_name\x94\x8c\x1722-02-2021_MacroConf-v2\x94\x8c\x0cdataset_file\x94\x8c3data/external/22-09-2021_MacroConf-v2.1/dataset.csv\x94\x8c\x0bsample_file\x94\x8c\x0bsamples.tsv\x94\x8c\rsample_output\x94\x8c\x0fsamples_old.tsv\x94\x8c\nforcefield\x94\x8c1libs/forcefields/leaprc.protein.ff14SB_noterminal\x94\x8c\x06jb-toc\x94\x8c\x13reports/jb/_toc.yml\x94\x8c\x08jb-links\x94\x8c\x11reports/jb/links/\x94\x8c\x0cDMSO_default\x94\x8c\x0eDMSO_GAFF_RESP\x94\x8c\rCDCl3_default\x94\x8c\nChloroform\x94\x8c\x0bDMSO_params\x94\x8c!libs/md_solvents/dmso/frcmod.dmso\x94\x8c\x08DMSO_box\x94\x8c!libs/md_solvents/dmso/dmsobox.off\x94\x8c\x11Chloroform_params\x94\x8c\x0cfrcmod.chcl3\x94\x8c\x13full_analysis_files\x94]\x94\x8c\x9b../../../data/processed/refactor-test/notebooks/methods/28159d44aa267024-native-586db4c575bef492-native_omega-basic-rdkit-ETKDGv3mmff-NOE_method_comp.ipynb\x94au\x8c\x04rule\x94\x8c\x12comp_solvent_props\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cG/biggin/b147/univ4859/research/03_macroconf/workflow/rules/../notebooks\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = False; import os; os.chdir(r'/biggin/b147/univ4859/research/03_macroconf/workflow');
######## snakemake preamble end #########

# %%
from src.utils import json_load, json_dump, pickle_load
# start coding here
gamd = json_load(snakemake.input.gamd)
cmd = json_load(snakemake.input.cmd)

# remove snakemake.input.gamd and snakemake.input.cmd from snakemake.input
snakemake.input = snakemake.input[:-2]


sasa = {}
psa = {}
for f in snakemake.input:
    id = f.split('/')[4]
    # if f ends with "sasa.json"
    if f.endswith('sasa.json'):
        sasa[id] = pickle_load(f)
    # if f ends with "psa.json"
    elif f.endswith('psa.json'):
        psa[id] = pickle_load(f)

# %%
confgen = snakemake.wildcards[0].capitalize()
mode = snakemake.wildcards[1].capitalize()

# %%
import matplotlib.pyplot as plt
import numpy as np

# make subplots for each id
fig, axs = plt.subplots(6, 6, figsize=(10, 10))

# iterative over sasa dict
for idx, (id, sa) in enumerate(sorted(sasa.items())):
    axs.flatten()[idx] = axs.flatten()[idx].hist(sa, bins=10)
    axs.flatten()[idx].set_title(id)
    # plot the gamd and cmd values as a vertical line
    if idx==0:
        axs.flatten()[idx].axvline(gamd['sasa'][id], color='r', linestyle='dashed', linewidth=1, label='GaMD')
        axs.flatten()[idx].axvline(cmd['sasa'][id], color='b', linestyle='dashed', linewidth=1, label='cMD')
    else:
        axs.flatten()[idx].axvline(gamd['sasa'][id], color='r', linestyle='dashed', linewidth=1)
    axs.flatten()[idx].axvline(cmd['sasa'][id], color='b', linestyle='dashed', linewidth=1)

for i in range(6):
    axs[5,i].set_xlabel('SASA [$nm^2$]')
    axs[i,0].set_ylabel('No. of cheminfor-\nmatics structures')

axs[5,5].axis('off')
axs[4,5].set_xlabel('SASA [$nm^2$]')

# save the figure
fig.suptitle(f"Comparison of Solvent Accessible Surface Area (SASA) for {confgen} {mode}")
fig.legend(loc=4)
fig.tight_layout()
fig.savefig(snakemake.output.plot_sasa, dpi=600)

# %%
import matplotlib.pyplot as plt
import numpy as np

# make subplots for each id
fig, axs = plt.subplots(6, 6, figsize=(10, 10))

# iterative over sasa dict
for idx, (id, ps) in enumerate(sorted(psa.items())):
    axs.flatten()[idx] = axs.flatten()[idx].hist(ps, bins=10)
    axs.flatten()[idx].set_title(id)
    # plot the gamd and cmd values as a vertical line
    if idx==0:
        axs.flatten()[idx].axvline(gamd['psa'][id], color='r', linestyle='dashed', linewidth=1, label='GaMD')
        axs.flatten()[idx].axvline(cmd['psa'][id], color='b', linestyle='dashed', linewidth=1, label='cMD')
    else:
        axs.flatten()[idx].axvline(gamd['psa'][id], color='r', linestyle='dashed', linewidth=1)
    axs.flatten()[idx].axvline(cmd['psa'][id], color='b', linestyle='dashed', linewidth=1)

for i in range(6):
    axs[5,i].set_xlabel('PSA [$nm^2$]')
    axs[i,0].set_ylabel('No. of cheminfor-\nmatics structures')

axs[5,5].axis('off')
axs[4,5].set_xlabel('PSA [$nm^2$]')

# save the figure
fig.suptitle(f"Comparison of Polar Surface Area (PSA) for {confgen} {mode}")
fig.legend(loc=4)
fig.tight_layout()
fig.savefig(snakemake.output.plot_psa, dpi=600)
